# %%
# 定义全局函数便于直接调用处理
from datetime import datetime

import pandas as pd
import numpy as np
from datetime import date
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import boxcox
datapath = 'D:/outsourcing/data/'
featurepath = 'D:/outsourcing/feature/'
resultpath = 'D:/outsourcing/result/'
tmppath = 'D:/outsourcing/tmp/'

# %%
BOX_Subtrain = pd.read_csv(tmppath+'BOX_Subtrain.csv')
#这是已经数据BOX变化，离散特征未处理的结果

# %%
BOX_Subtrain.head(10)
# Out:
#   seg_flight seg_cabin  tkt_all_amt_y2   pax_tax  tkt_avg_amt_m6  \
# 0     AB1006         J         0.00496  0.000793             0.0
# 1     AB1006         J         0.01027  0.000341             0.0
# 2     AB1009         Y         0.00496  0.000413             0.0
# 3     AB1009         Y         0.00496  0.000619             0.0
# 4     AB1010         Y         0.00496  0.000389             0.0
# 5     AB1009         Y         0.00496  0.000409             0.0
# 6     AB1006         Y         0.00496  0.000401             0.0
# 7     AB1006         Y         0.00496  0.000618             0.0
# 8     AB1006         Y         0.00677  0.000410             0.0
# 9     AB1008         Y         0.00496  0.000602             0.0
#
#    tkt_avg_amt_y1  dist_cnt_y3  tkt_avg_amt_y2  pax_fcny  tkt_all_amt_y1  ...  \
# 0        0.000000      0.00000        0.009770  0.000892         0.00000  ...
# 1        0.004982      0.00000        0.011790  0.000378         0.00573  ...
# ...

# %%
BOX_Subtrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23432 entries, 0 to 23431
# Data columns (total 45 columns):
# seg_flight            23432 non-null object
# seg_cabin             23432 non-null object
# tkt_all_amt_y2        23432 non-null float64
# pax_tax               23432 non-null float64
# tkt_avg_amt_m6        23432 non-null float64
# tkt_avg_amt_y1        23432 non-null float64
# dist_cnt_y3           23432 non-null float64
# tkt_avg_amt_y2        23432 non-null float64
# pax_fcny              23432 non-null float64
# tkt_all_amt_y1        23432 non-null float64
# pref_orig_m6_2        23432 non-null object
# avg_dist_cnt_y1       23432 non-null float64
# avg_dist_cnt_y2       23432 non-null float64
# select_seat_cnt_y2    23432 non-null float64
# select_seat_cnt_y3    23432 non-null float64
# pit_all_amt           23432 non-null float64
# dist_i_cnt_y2         23432 non-null float64
# dist_i_cnt_y3         23432 non-null float64
# ...

# %%
BOX_Subtest = pd.read_csv(tmppath+'BOX_Subtest.csv')
#这是已经数据BOX变化，离散特征未处理的结果

# %%
BOX_Subtest.head(10)
# Out:
#   seg_flight seg_cabin  tkt_all_amt_y2   pax_tax  tkt_avg_amt_m6  \
# 0     AB1010         Y        0.009865  0.000313         0.00287
# 1     AB1008         Y        0.004960  0.000343         0.00000
# 2     AB1010         Y        0.006096  0.000561         0.00000
# 3     AB1009         Y        0.004960  0.000775         0.00000
# 4     AB1006         Y        0.004960  0.000383         0.00000
# 5     AB1010         Y        0.004960  0.000557         0.00000
# 6     AB1006         Y        0.007656  0.000573         0.00000
# 7     AB1006         Y        0.004960  0.000384         0.00000
# 8     AB1008         Y        0.004960  0.000361         0.00000
# 9     AB1009         Y        0.008835  0.000620         0.00000
#
#    tkt_avg_amt_y1  dist_cnt_y3  tkt_avg_amt_y2  pax_fcny  tkt_all_amt_y1  ...  \
# 0        0.004704      0.00000        0.011110  0.000079        0.005592  ...
# 1        0.000000      0.00000        0.009770  0.000059        0.000000  ...
# ...

# %%
Subtrain = pd.read_csv(tmppath+'Subtrain.csv')

# %%
Subtrain.head(10)
# Out:
#   seg_flight seg_cabin  tkt_all_amt_y2  pax_tax  tkt_avg_amt_m6  \
# 0     AB1006         J            0.00   584.43             0.0
# 1     AB1006         J         9760.67   248.80             0.0
# 2     AB1009         Y            0.00   301.31             0.0
# 3     AB1009         Y            0.00   454.16             0.0
# 4     AB1010         Y            0.00   284.11             0.0
# 5     AB1009         Y            0.00   298.23             0.0
# 6     AB1006         Y            0.00   292.73             0.0
# 7     AB1006         Y            0.00   453.66             0.0
# 8     AB1006         Y         1255.28   299.61             0.0
# 9     AB1008         Y            0.00   441.96             0.0
#
#    tkt_avg_amt_y1  dist_cnt_y3  tkt_avg_amt_y2  pax_fcny  tkt_all_amt_y1  ...  \
# 0             0.0            0             0.0    4161.0            0.00  ...
# 1          2950.0            0          3254.0    1670.0         8850.67  ...
# ...

# %%
Subtest = pd.read_csv(tmppath+'Subtest.csv')

# %%
Subtest.head(10)
# Out:
#   seg_flight seg_cabin  tkt_all_amt_y2  pax_tax  tkt_avg_amt_m6  \
# 0     AB1010         Y         6821.75   227.81           104.2
# 1     AB1008         Y            0.00   250.15             0.0
# 2     AB1010         Y          728.85   411.21             0.0
# 3     AB1009         Y            0.00   571.60             0.0
# 4     AB1006         Y            0.00   279.66             0.0
# 5     AB1010         Y            0.00   407.75             0.0
# 6     AB1006         Y         2117.98   419.83             0.0
# 7     AB1006         Y            0.00   279.86             0.0
# 8     AB1008         Y            0.00   263.45             0.0
# 9     AB1009         Y         3813.83   455.51             0.0
#
#    tkt_avg_amt_y1  dist_cnt_y3  tkt_avg_amt_y2  pax_fcny  tkt_all_amt_y1  ...  \
# 0           282.2            0           525.0     339.0         3669.34  ...
# 1             0.0            0             0.0     255.0            0.00  ...
# ...

# %%
X_train.head(5)
# Out:
#   seg_flight seg_cabin  tkt_all_amt_y2   pax_tax  tkt_avg_amt_m6  \
# 0     AB1006         J         0.00496  0.000793             0.0
# 1     AB1006         J         0.01027  0.000341             0.0
# 2     AB1009         Y         0.00496  0.000413             0.0
# 3     AB1009         Y         0.00496  0.000619             0.0
# 4     AB1010         Y         0.00496  0.000389             0.0
#
#    tkt_avg_amt_y1  dist_cnt_y3  tkt_avg_amt_y2  pax_fcny  tkt_all_amt_y1  ...  \
# 0        0.000000      0.00000         0.00977  0.000892         0.00000  ...
# 1        0.004982      0.00000         0.01179  0.000378         0.00573  ...
# 2        0.000000      0.00000         0.00977  0.000057         0.00000  ...
# 3        0.000000      0.01813         0.00977  0.000310         0.00000  ...
# 4        0.000000      0.02075         0.00977  0.000156         0.00000  ...
#
#   select_seat_cnt_y3_multi_tkt_avg_amt_y1  \
# 0                                0.000000
# ...
