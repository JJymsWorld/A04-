# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import balanced_accuracy_score, accuracy_score, recall_score, precision_score, auc, confusion_matrix, f1_score, roc_auc_score
from xgboost.sklearn import XGBClassifier
from collections import Counter
import xgboost as xgb
from imblearn.over_sampling import SMOTE

# %%
from base import reduce_mem_usage, read_csv, datapath, drop_features, tmppath, Box_Cox, train_drop_features, getTrainTest, minmax_target, combine_feature, auto_feature_make

# %%
train = reduce_mem_usage(read_csv(tmppath + '10FoldSubTrain.csv'))
test = reduce_mem_usage(read_csv(tmppath + '10FoldSubTest.csv'))
# Out:
# Memory usage after optimization is: 6.57 MB
# Decreased by 47.5%
# Memory usage after optimization is: 1.90 MB
# Decreased by 47.5%

# %%
X_train = train.drop(['emd_lable2'], axis=1)
Y_train = train['emd_lable2'].astype(int)
test = test.drop(['emd_lable2'], axis=1)

# %%
discrete_list = ['seg_cabin','seg_flight','pref_line_y2_2','pref_line_y1_2','pref_line_y3_4','pref_line_y3_3','pref_line_y2_1','pref_city_y3_2','pref_city_y2_3','pref_line_y3_5','pref_line_y2_4','pref_city_y2_2','pref_line_y3_2','pref_line_y2_5','pref_line_y2_3','pref_orig_city_y3','pref_city_y3_3','pref_line_y3_1','pref_orig_y2_2','seg_route_to','pref_orig_y3_3','pref_orig_city_y2','pref_line_y1_3','pref_line_m3_3','pref_aircraft_y3_3','pref_aircraft_y2_5','seg_dep_time_hour']

# %%
feature_list = X_train.columns.tolist()
continue_list = list(set(feature_list) - set(discrete_list))

# %%
X_train, X_test = minmax_target(X_train, test, Y_train, continue_list, discrete_list) # 离散值编码与连续特征归一化
# Out:
# D:\anaconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
x_train, x_test, y_train, y_test =getTrainTest(X_train, Y_train)# 线下验证，80%训练集，20%验证集

# %%
dtrain = xgb.DMatrix(x_train[continue_list].values, label=y_train.values)
dtest = xgb.DMatrix(x_test[continue_list].values, label=y_test.values)

# %% [markdown]
# ### 初始化自定义参数
#
#
# # 存在问题1：cv函数确定迭代次数的方法，dtrain只使用了连续特征的数据
# # 存在问题2： GridSearch使用cv==5,对不平衡数据可能存在偏差，应该使用Straifield生成的折叠器

# %%
xgb1 = XGBClassifier(max_depth=5,
                     learning_rate=0.1,
                     n_estimators=10000,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0,
                     min_child_weight=1,
                     subsample=0.8,
                     colsample_bytree=0.8,
                     seed=27)

# %% [markdown]
# 测试在初始化自定义参数下的得分结果

# %%
xgb_bst1 = xgb1.fit(x_train, y_train)
y_pred = xgb_bst1.predict(x_test)
y_pred2 = xgb_bst1.predict(x_train)
print("XGBoost结果")
print("balanced_accuracy_score=", balanced_accuracy_score(y_pred=y_pred, y_true=y_test),balanced_accuracy_score(y_pred=y_pred2, y_true=y_train))
print("f1=", f1_score(y_pred=y_pred, y_true=y_test), f1_score(y_pred=y_pred2, y_true=y_train))
print("precision_score=", precision_score(y_pred=y_pred, y_true=y_test),precision_score(y_pred=y_pred2, y_true=y_train))
print("recall_score=", recall_score(y_pred=y_pred, y_true=y_test), recall_score(y_pred=y_pred2, y_true=y_train))
print("accuracy=", accuracy_score(y_pred=y_pred, y_true=y_test), accuracy_score(y_pred=y_pred2, y_true=y_train))
print("auc=", roc_auc_score(y_true=y_test, y_score=y_pred), roc_auc_score(y_true=y_train, y_score=y_pred2))
print("#####混淆矩阵#########")
print(confusion_matrix(y_true=y_test, y_pred=y_pred), confusion_matrix(y_true=y_train, y_pred=y_pred2))
# Out:
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:08:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost结果
# balanced_accuracy_score= 0.6539459263375629 0.9818870104744122
# f1= 0.41025641025641024 0.9714285714285714
# precision_score= 0.5549132947976878 0.9776824034334763
# recall_score= 0.3254237288135593 0.9652542372881356
# accuracy= 0.9411137187966716 0.9964257135236063
# auc= 0.6539459263375629 0.9818870104744122
# #####混淆矩阵#########
# [[4315   77]
#  [ 199   96]] [[17539    26]
#  [   41  1139]]

# %% [markdown]
# 在当前学习率下利用cv函数获得最佳的迭代次数

# %%
cv_result = xgb.cv(xgb1.get_xgb_params(),
dtrain,
num_boost_round=xgb1.get_params()['n_estimators'],
nfold=5,
metrics='auc',
early_stopping_rounds=100,
callbacks=[xgb.callback.early_stop(100),
xgb.callback.print_evaluation(period=1,show_stdv=True)])
# Out:
# st-auc:0.76771+0.02130
# [463]	train-auc:0.97140+0.00097	test-auc:0.76791+0.02127
# [464]	train-auc:0.97152+0.00090	test-auc:0.76785+0.02118
# [465]	train-auc:0.97157+0.00094	test-auc:0.76793+0.02110
# [466]	train-auc:0.97162+0.00093	test-auc:0.76786+0.02123
# [467]	train-auc:0.97169+0.00095	test-auc:0.76793+0.02109
# [468]	train-auc:0.97176+0.00099	test-auc:0.76790+0.02114
# [469]	train-auc:0.97187+0.00101	test-auc:0.76779+0.02122
# [470]	train-auc:0.97192+0.00103	test-auc:0.76772+0.02108
# [471]	train-auc:0.97197+0.00107	test-auc:0.76770+0.02101
# [472]	train-auc:0.97198+0.00106	test-auc:0.76770+0.02100
# [473]	train-auc:0.97204+0.00105	test-auc:0.76783+0.02084
# [474]	train-auc:0.97211+0.00103	test-auc:0.76792+0.02093
# [475]	train-auc:0.97217+0.00104	test-auc:0.76785+0.02110
# [476]	train-auc:0.97222+0.00104	test-auc:0.76783+0.02106
# [477]	train-auc:0.97231+0.00105	test-auc:0.76801+0.02101
# [478]	train-auc:0.97240+0.00110	test-auc:0.76784+0.02084
# [479]	train-auc:0.97249+0.00109	test-auc:0.76789+0.02081
# [480]	train-auc:0.97257+0.00115	test-auc:0.76763+0.02085
# [481]	train-auc:0.97264+0.00111	test-auc:0.76768+0.02079
# [482]	train-auc:0.97269+0.00113	test-auc:0.76780+0.02093
# [483]	train-auc:0.97282+0.00108	test-auc:0.76782+0.02092
# [484]	train-auc:0.97293+0.00102	test-auc:0.76773+0.02102
# [485]	train-auc:0.97302+0.00102	test-auc:0.76769+0.02087
# [486]	train-auc:0.97320+0.00103	test-auc:0.76773+0.02093
# [487]	train-auc:0.97326+0.00101	test-auc:0.76766+0.02111
# [488]	train-auc:0.97334+0.00102	test-auc:0.76783+0.02112
# [489]	train-auc:0.97351+0.00102	test-auc:0.76803+0.02111
# [490]	train-auc:0.97356+0.00102	test-auc:0.76802+0.02115
# [491]	train-auc:0.97358+0.00102	test-auc:0.76807+0.02122
# [492]	train-auc:0.97365+0.00104	test-auc:0.76801+0.02143
# [493]	train-auc:0.97377+0.00106	test-auc:0.76789+0.02129
# [494]	train-auc:0.97383+0.00107	test-auc:0.76799+0.02130
# [495]	train-auc:0.97392+0.00106	test-auc:0.76799+0.02143
# [496]	train-auc:0.97398+0.00105	test-auc:0.76789+0.02146
# [497]	train-auc:0.97410+0.00103	test-auc:0.76785+0.02130
# [498]	train-auc:0.97422+0.00106	test-auc:0.76795+0.02129
# [499]	train-auc:0.97427+0.00104	test-auc:0.76795+0.02125
# [500]	train-auc:0.97433+0.00107	test-auc:0.76790+0.02123
# [501]	train-auc:0.97440+0.00109	test-auc:0.76796+0.02124
# [502]	train-auc:0.97450+0.00105	test-auc:0.76785+0.02112
# [503]	train-auc:0.97456+0.00106	test-auc:0.76771+0.02122
# [504]	train-auc:0.97461+0.00104	test-auc:0.76791+0.02138
# [505]	train-auc:0.97473+0.00101	test-auc:0.76803+0.02144
# [506]	train-auc:0.97480+0.00101	test-auc:0.76785+0.02127
# [507]	train-auc:0.97484+0.00102	test-auc:0.76785+0.02138
# [508]	train-auc:0.97488+0.00100	test-auc:0.76779+0.02142
# [509]	train-auc:0.97498+0.00106	test-auc:0.76788+0.02127
# [510]	train-auc:0.97505+0.00108	test-auc:0.76795+0.02129
# [511]	train-auc:0.97509+0.00106	test-auc:0.76794+0.02148
# [512]	train-auc:0.97516+0.00105	test-auc:0.76785+0.02166
# [513]	train-auc:0.97520+0.00108	test-auc:0.76782+0.02199
# [514]	train-auc:0.97528+0.00113	test-auc:0.76785+0.02184
# [515]	train-auc:0.97535+0.00113	test-auc:0.76778+0.02177
# [516]	train-auc:0.97538+0.00116	test-auc:0.76783+0.02174
# [517]	train-auc:0.97545+0.00121	test-auc:0.76768+0.02170
# [518]	train-auc:0.97551+0.00119	test-auc:0.76772+0.02154
# [519]	train-auc:0.97559+0.00118	test-auc:0.76755+0.02153
# [520]	train-auc:0.97569+0.00115	test-auc:0.76750+0.02160
# [521]	train-auc:0.97572+0.00118	test-auc:0.76748+0.02157
# [522]	train-auc:0.97580+0.00124	test-auc:0.76753+0.02141
# [523]	train-auc:0.97583+0.00122	test-auc:0.76753+0.02124
# [524]	train-auc:0.97591+0.00120	test-auc:0.76754+0.02116
# [525]	train-auc:0.97597+0.00118	test-auc:0.76762+0.02110
# [526]	train-auc:0.97597+0.00120	test-auc:0.76787+0.02111
# [527]	train-auc:0.97606+0.00115	test-auc:0.76789+0.02091
# [528]	train-auc:0.97611+0.00116	test-auc:0.76787+0.02078
# [529]	train-auc:0.97620+0.00118	test-auc:0.76791+0.02083
# [530]	train-auc:0.97627+0.00121	test-auc:0.76777+0.02082
# [531]	train-auc:0.97634+0.00123	test-auc:0.76765+0.02093
# [532]	train-auc:0.97638+0.00122	test-auc:0.76761+0.02075
# [533]	train-auc:0.97645+0.00123	test-auc:0.76772+0.02071
# [534]	train-auc:0.97653+0.00124	test-auc:0.76770+0.02066
# [535]	train-auc:0.97657+0.00124	test-auc:0.76772+0.02064
# [536]	train-auc:0.97665+0.00121	test-auc:0.76776+0.02061
# [537]	train-auc:0.97668+0.00118	test-auc:0.76773+0.02062
# [538]	train-auc:0.97672+0.00120	test-auc:0.76774+0.02063
# [539]	train-auc:0.97680+0.00121	test-auc:0.76765+0.02069
# [540]	train-auc:0.97689+0.00124	test-auc:0.76760+0.02067
# [541]	train-auc:0.97694+0.00120	test-auc:0.76767+0.02052
# [542]	train-auc:0.97701+0.00117	test-auc:0.76770+0.02032
# [543]	train-auc:0.97705+0.00119	test-auc:0.76771+0.02034
# [544]	train-auc:0.97718+0.00116	test-auc:0.76761+0.02043
# [545]	train-auc:0.97725+0.00114	test-auc:0.76776+0.02049
# [546]	train-auc:0.97731+0.00117	test-auc:0.76786+0.02051
# [547]	train-auc:0.97740+0.00117	test-auc:0.76795+0.02064
# [548]	train-auc:0.97747+0.00119	test-auc:0.76782+0.02062
# [549]	train-auc:0.97754+0.00117	test-auc:0.76760+0.02052
# [550]	train-auc:0.97759+0.00115	test-auc:0.76771+0.02054
# [551]	train-auc:0.97766+0.00113	test-auc:0.76767+0.02058
# [552]	train-auc:0.97775+0.00116	test-auc:0.76775+0.02047
# [553]	train-auc:0.97781+0.00118	test-auc:0.76765+0.02049
# [554]	train-auc:0.97788+0.00114	test-auc:0.76766+0.02055
# [555]	train-auc:0.97791+0.00110	test-auc:0.76775+0.02046
# [556]	train-auc:0.97794+0.00112	test-auc:0.76796+0.02046
# [557]	train-auc:0.97803+0.00110	test-auc:0.76794+0.02044
# [558]	train-auc:0.97806+0.00111	test-auc:0.76803+0.02043
# [559]	train-auc:0.97810+0.00111	test-auc:0.76788+0.02041
# [560]	train-auc:0.97817+0.00110	test-auc:0.76785+0.02037
# [561]	train-auc:0.97818+0.00111	test-auc:0.76782+0.02043
# [562]	train-auc:0.97826+0.00108	test-auc:0.76784+0.02045
# [563]	train-auc:0.97833+0.00106	test-auc:0.76763+0.02024
# [564]	train-auc:0.97840+0.00108	test-auc:0.76752+0.02022
# [565]	train-auc:0.97845+0.00110	test-auc:0.76777+0.02034
# [566]	train-auc:0.97851+0.00108	test-auc:0.76785+0.02043
# [567]	train-auc:0.97861+0.00110	test-auc:0.76773+0.02031
# [568]	train-auc:0.97865+0.00107	test-auc:0.76781+0.02025
# [569]	train-auc:0.97869+0.00107	test-auc:0.76803+0.02028
# [570]	train-auc:0.97876+0.00103	test-auc:0.76798+0.02013
# [571]	train-auc:0.97883+0.00105	test-auc:0.76815+0.02016
# [572]	train-auc:0.97888+0.00106	test-auc:0.76828+0.02012
# [573]	train-auc:0.97893+0.00106	test-auc:0.76825+0.02016
# [574]	train-auc:0.97903+0.00107	test-auc:0.76818+0.02011
# [575]	train-auc:0.97910+0.00105	test-auc:0.76816+0.01991
# [576]	train-auc:0.97915+0.00106	test-auc:0.76800+0.02007
# [577]	train-auc:0.97924+0.00107	test-auc:0.76803+0.02012
# [578]	train-auc:0.97930+0.00107	test-auc:0.76786+0.02012
# [579]	train-auc:0.97942+0.00106	test-auc:0.76789+0.02017
# [580]	train-auc:0.97949+0.00107	test-auc:0.76787+0.02039
# [581]	train-auc:0.97956+0.00107	test-auc:0.76798+0.02057
# [582]	train-auc:0.97967+0.00109	test-auc:0.76806+0.02027
# [583]	train-auc:0.97976+0.00114	test-auc:0.76827+0.02026
# [584]	train-auc:0.97982+0.00116	test-auc:0.76845+0.02039
# [585]	train-auc:0.97985+0.00115	test-auc:0.76858+0.02048
# [586]	train-auc:0.97988+0.00113	test-auc:0.76850+0.02055
# [587]	train-auc:0.97990+0.00114	test-auc:0.76852+0.02052
# [588]	train-auc:0.97993+0.00113	test-auc:0.76853+0.02049
# [589]	train-auc:0.97995+0.00113	test-auc:0.76846+0.02048
# [590]	train-auc:0.98000+0.00116	test-auc:0.76858+0.02046
# [591]	train-auc:0.98007+0.00121	test-auc:0.76847+0.02060
# [592]	train-auc:0.98010+0.00122	test-auc:0.76856+0.02061
# [593]	train-auc:0.98014+0.00125	test-auc:0.76858+0.02052
# [594]	train-auc:0.98018+0.00125	test-auc:0.76859+0.02058
# [595]	train-auc:0.98023+0.00124	test-auc:0.76872+0.02062
# [596]	train-auc:0.98028+0.00127	test-auc:0.76866+0.02045
# [597]	train-auc:0.98032+0.00129	test-auc:0.76869+0.02037
# [598]	train-auc:0.98032+0.00128	test-auc:0.76869+0.02032
# [599]	train-auc:0.98035+0.00129	test-auc:0.76882+0.02030
# [600]	train-auc:0.98042+0.00128	test-auc:0.76861+0.02023
# [601]	train-auc:0.98048+0.00130	test-auc:0.76869+0.02010
# [602]	train-auc:0.98052+0.00127	test-auc:0.76852+0.01994
# [603]	train-auc:0.98056+0.00128	test-auc:0.76844+0.01988
# [604]	train-auc:0.98064+0.00127	test-auc:0.76855+0.01993
# [605]	train-auc:0.98072+0.00129	test-auc:0.76847+0.01986
# [606]	train-auc:0.98075+0.00125	test-auc:0.76853+0.01988
# [607]	train-auc:0.98079+0.00123	test-auc:0.76845+0.01987
# [608]	train-auc:0.98081+0.00118	test-auc:0.76845+0.01981
# [609]	train-auc:0.98083+0.00119	test-auc:0.76859+0.01982
# [610]	train-auc:0.98089+0.00117	test-auc:0.76855+0.01991
# [611]	train-auc:0.98097+0.00111	test-auc:0.76831+0.01982
# [612]	train-auc:0.98099+0.00111	test-auc:0.76823+0.01978
# [613]	train-auc:0.98101+0.00112	test-auc:0.76835+0.01959
# [614]	train-auc:0.98110+0.00105	test-auc:0.76849+0.01944
# [615]	train-auc:0.98115+0.00105	test-auc:0.76858+0.01955
# [616]	train-auc:0.98118+0.00107	test-auc:0.76848+0.01953
# [617]	train-auc:0.98123+0.00105	test-auc:0.76845+0.01959
# [618]	train-auc:0.98126+0.00107	test-auc:0.76854+0.01952
# [619]	train-auc:0.98128+0.00105	test-auc:0.76844+0.01964
# [620]	train-auc:0.98131+0.00106	test-auc:0.76834+0.01965
# [621]	train-auc:0.98138+0.00106	test-auc:0.76844+0.01964
# [622]	train-auc:0.98145+0.00104	test-auc:0.76841+0.01976
# [623]	train-auc:0.98148+0.00106	test-auc:0.76837+0.01986
# [624]	train-auc:0.98155+0.00108	test-auc:0.76832+0.01988
# [625]	train-auc:0.98160+0.00111	test-auc:0.76814+0.02006
# [626]	train-auc:0.98160+0.00109	test-auc:0.76815+0.02019
# [627]	train-auc:0.98165+0.00109	test-auc:0.76817+0.02002
# [628]	train-auc:0.98169+0.00109	test-auc:0.76809+0.02006
# [629]	train-auc:0.98176+0.00104	test-auc:0.76818+0.02012
# [630]	train-auc:0.98179+0.00105	test-auc:0.76817+0.02006
# [631]	train-auc:0.98185+0.00106	test-auc:0.76818+0.02008
# [632]	train-auc:0.98187+0.00107	test-auc:0.76819+0.02005
# [633]	train-auc:0.98190+0.00104	test-auc:0.76820+0.02018
# [634]	train-auc:0.98194+0.00101	test-auc:0.76838+0.02006
# [635]	train-auc:0.98197+0.00102	test-auc:0.76835+0.02021
# [636]	train-auc:0.98200+0.00103	test-auc:0.76845+0.02010
# [637]	train-auc:0.98206+0.00101	test-auc:0.76840+0.02030
# [638]	train-auc:0.98213+0.00101	test-auc:0.76849+0.02018
# [639]	train-auc:0.98216+0.00103	test-auc:0.76866+0.02010
# [640]	train-auc:0.98220+0.00100	test-auc:0.76858+0.02005
# [641]	train-auc:0.98224+0.00103	test-auc:0.76862+0.01997
# [642]	train-auc:0.98226+0.00102	test-auc:0.76853+0.01998
# [643]	train-auc:0.98230+0.00102	test-auc:0.76863+0.02000
# [644]	train-auc:0.98233+0.00102	test-auc:0.76865+0.01989
# [645]	train-auc:0.98238+0.00102	test-auc:0.76863+0.01998
# [646]	train-auc:0.98241+0.00102	test-auc:0.76872+0.01992
# [647]	train-auc:0.98244+0.00100	test-auc:0.76878+0.01996
# [648]	train-auc:0.98246+0.00102	test-auc:0.76877+0.01990
# [649]	train-auc:0.98249+0.00101	test-auc:0.76874+0.01974
# [650]	train-auc:0.98256+0.00101	test-auc:0.76894+0.02000
# [651]	train-auc:0.98260+0.00099	test-auc:0.76886+0.02004
# [652]	train-auc:0.98263+0.00098	test-auc:0.76875+0.02015
# [653]	train-auc:0.98268+0.00099	test-auc:0.76887+0.01996
# [654]	train-auc:0.98271+0.00101	test-auc:0.76902+0.02001
# [655]	train-auc:0.98272+0.00102	test-auc:0.76909+0.02003
# [656]	train-auc:0.98276+0.00104	test-auc:0.76905+0.02010
# [657]	train-auc:0.98279+0.00104	test-auc:0.76937+0.01994
# [658]	train-auc:0.98281+0.00110	test-auc:0.76954+0.01994
# [659]	train-auc:0.98287+0.00111	test-auc:0.76953+0.01998
# [660]	train-auc:0.98291+0.00110	test-auc:0.76959+0.01985
# [661]	train-auc:0.98294+0.00109	test-auc:0.76960+0.01996
# [662]	train-auc:0.98298+0.00106	test-auc:0.76956+0.01993
# [663]	train-auc:0.98304+0.00107	test-auc:0.76949+0.01983
# [664]	train-auc:0.98306+0.00109	test-auc:0.76949+0.01987
# [665]	train-auc:0.98308+0.00108	test-auc:0.76965+0.01988
# [666]	train-auc:0.98311+0.00109	test-auc:0.76967+0.02004
# [667]	train-auc:0.98314+0.00113	test-auc:0.76980+0.02011
# [668]	train-auc:0.98319+0.00110	test-auc:0.76972+0.02024
# [669]	train-auc:0.98323+0.00112	test-auc:0.76970+0.02027
# [670]	train-auc:0.98328+0.00108	test-auc:0.76959+0.02042
# [671]	train-auc:0.98333+0.00103	test-auc:0.76950+0.02049
# [672]	train-auc:0.98340+0.00105	test-auc:0.76945+0.02065
# [673]	train-auc:0.98344+0.00104	test-auc:0.76945+0.02056
# [674]	train-auc:0.98345+0.00105	test-auc:0.76942+0.02034
# [675]	train-auc:0.98350+0.00109	test-auc:0.76952+0.02015
# [676]	train-auc:0.98354+0.00109	test-auc:0.76952+0.01999
# [677]	train-auc:0.98360+0.00101	test-auc:0.76947+0.01993
# [678]	train-auc:0.98363+0.00100	test-auc:0.76963+0.01991
# [679]	train-auc:0.98369+0.00100	test-auc:0.76956+0.01997
# [680]	train-auc:0.98373+0.00102	test-auc:0.76950+0.01989
# [681]	train-auc:0.98377+0.00102	test-auc:0.76943+0.01991
# [682]	train-auc:0.98381+0.00104	test-auc:0.76943+0.01982
# [683]	train-auc:0.98388+0.00101	test-auc:0.76929+0.01989
# [684]	train-auc:0.98394+0.00104	test-auc:0.76934+0.01997
# [685]	train-auc:0.98395+0.00106	test-auc:0.76939+0.01988
# [686]	train-auc:0.98400+0.00105	test-auc:0.76939+0.01992
# [687]	train-auc:0.98403+0.00105	test-auc:0.76933+0.01988
# [688]	train-auc:0.98407+0.00106	test-auc:0.76932+0.01978
# [689]	train-auc:0.98413+0.00103	test-auc:0.76936+0.01983
# [690]	train-auc:0.98415+0.00105	test-auc:0.76938+0.01979
# [691]	train-auc:0.98421+0.00107	test-auc:0.76939+0.01971
# [692]	train-auc:0.98423+0.00107	test-auc:0.76945+0.01986
# [693]	train-auc:0.98424+0.00107	test-auc:0.76935+0.01988
# [694]	train-auc:0.98426+0.00107	test-auc:0.76936+0.01991
# [695]	train-auc:0.98430+0.00108	test-auc:0.76938+0.01993
# [696]	train-auc:0.98432+0.00108	test-auc:0.76939+0.01992
# [697]	train-auc:0.98436+0.00110	test-auc:0.76942+0.02000
# [698]	train-auc:0.98440+0.00110	test-auc:0.76959+0.02007
# [699]	train-auc:0.98441+0.00109	test-auc:0.76957+0.02007
# [700]	train-auc:0.98442+0.00111	test-auc:0.76971+0.01995
# [701]	train-auc:0.98446+0.00115	test-auc:0.76973+0.01994
# [702]	train-auc:0.98448+0.00114	test-auc:0.76974+0.01999
# [703]	train-auc:0.98450+0.00116	test-auc:0.76976+0.01988
# [704]	train-auc:0.98451+0.00115	test-auc:0.76985+0.01981
# [705]	train-auc:0.98453+0.00112	test-auc:0.76983+0.01999
# [706]	train-auc:0.98457+0.00111	test-auc:0.76988+0.02002
# [707]	train-auc:0.98462+0.00111	test-auc:0.76983+0.02007
# [708]	train-auc:0.98465+0.00111	test-auc:0.76980+0.02014
# [709]	train-auc:0.98468+0.00111	test-auc:0.76986+0.02024
# [710]	train-auc:0.98470+0.00112	test-auc:0.76982+0.02005
# [711]	train-auc:0.98475+0.00111	test-auc:0.76982+0.02017
# [712]	train-auc:0.98478+0.00111	test-auc:0.76990+0.02022
# [713]	train-auc:0.98481+0.00112	test-auc:0.76982+0.02020
# [714]	train-auc:0.98484+0.00112	test-auc:0.76981+0.02008
# [715]	train-auc:0.98487+0.00110	test-auc:0.76967+0.02009
# [716]	train-auc:0.98492+0.00107	test-auc:0.76968+0.02002
# [717]	train-auc:0.98498+0.00107	test-auc:0.76958+0.01994
# [718]	train-auc:0.98501+0.00108	test-auc:0.76961+0.01976
# [719]	train-auc:0.98504+0.00111	test-auc:0.76988+0.01970
# [720]	train-auc:0.98506+0.00111	test-auc:0.76984+0.01970
# [721]	train-auc:0.98508+0.00110	test-auc:0.76968+0.01968
# [722]	train-auc:0.98510+0.00109	test-auc:0.76963+0.01964
# [723]	train-auc:0.98515+0.00107	test-auc:0.76949+0.01971
# [724]	train-auc:0.98519+0.00106	test-auc:0.76939+0.01969
# [725]	train-auc:0.98522+0.00104	test-auc:0.76936+0.01977
# [726]	train-auc:0.98524+0.00105	test-auc:0.76945+0.01971
# [727]	train-auc:0.98529+0.00105	test-auc:0.76957+0.01967
# [728]	train-auc:0.98531+0.00105	test-auc:0.76932+0.01972
# [729]	train-auc:0.98532+0.00104	test-auc:0.76934+0.01976
# [730]	train-auc:0.98532+0.00104	test-auc:0.76928+0.01982
# [731]	train-auc:0.98534+0.00108	test-auc:0.76933+0.01967
# [732]	train-auc:0.98534+0.00108	test-auc:0.76931+0.01964
# [733]	train-auc:0.98536+0.00108	test-auc:0.76924+0.01966
# [734]	train-auc:0.98540+0.00106	test-auc:0.76914+0.01983
# [735]	train-auc:0.98543+0.00107	test-auc:0.76924+0.01979
# [736]	train-auc:0.98548+0.00112	test-auc:0.76934+0.01989
# [737]	train-auc:0.98552+0.00109	test-auc:0.76932+0.01983
# [738]	train-auc:0.98553+0.00109	test-auc:0.76940+0.01976
# [739]	train-auc:0.98560+0.00110	test-auc:0.76934+0.01985
# [740]	train-auc:0.98561+0.00113	test-auc:0.76942+0.01985
# [741]	train-auc:0.98565+0.00110	test-auc:0.76931+0.01976
# [742]	train-auc:0.98568+0.00108	test-auc:0.76925+0.01960
# [743]	train-auc:0.98573+0.00111	test-auc:0.76921+0.01953
# [744]	train-auc:0.98576+0.00108	test-auc:0.76912+0.01938
# [745]	train-auc:0.98579+0.00107	test-auc:0.76908+0.01937
# [746]	train-auc:0.98584+0.00108	test-auc:0.76898+0.01934
# [747]	train-auc:0.98587+0.00109	test-auc:0.76902+0.01939
# [748]	train-auc:0.98591+0.00106	test-auc:0.76904+0.01937
# [749]	train-auc:0.98592+0.00108	test-auc:0.76909+0.01946
# [750]	train-auc:0.98596+0.00108	test-auc:0.76926+0.01934
# [751]	train-auc:0.98597+0.00107	test-auc:0.76924+0.01930
# [752]	train-auc:0.98598+0.00110	test-auc:0.76921+0.01920
# [753]	train-auc:0.98602+0.00109	test-auc:0.76917+0.01926
# [754]	train-auc:0.98605+0.00108	test-auc:0.76912+0.01931
# [755]	train-auc:0.98609+0.00110	test-auc:0.76911+0.01922
# [756]	train-auc:0.98611+0.00109	test-auc:0.76904+0.01915
# [757]	train-auc:0.98616+0.00109	test-auc:0.76912+0.01903
# [758]	train-auc:0.98614+0.00111	test-auc:0.76913+0.01903
# [759]	train-auc:0.98618+0.00110	test-auc:0.76911+0.01908
# [760]	train-auc:0.98621+0.00110	test-auc:0.76913+0.01912
# [761]	train-auc:0.98622+0.00112	test-auc:0.76921+0.01907
# [762]	train-auc:0.98626+0.00111	test-auc:0.76911+0.01914
# [763]	train-auc:0.98626+0.00111	test-auc:0.76905+0.01914
# [764]	train-auc:0.98628+0.00111	test-auc:0.76902+0.01908
# [765]	train-auc:0.98632+0.00111	test-auc:0.76888+0.01905
# [766]	train-auc:0.98634+0.00113	test-auc:0.76893+0.01901
# [767]	train-auc:0.98635+0.00112	test-auc:0.76883+0.01900
# [768]	train-auc:0.98639+0.00108	test-auc:0.76873+0.01906
# [769]	train-auc:0.98639+0.00111	test-auc:0.76861+0.01900
# [770]	train-auc:0.98641+0.00112	test-auc:0.76862+0.01904
# [771]	train-auc:0.98644+0.00112	test-auc:0.76850+0.01916
# [772]	train-auc:0.98648+0.00112	test-auc:0.76851+0.01911
# [773]	train-auc:0.98649+0.00110	test-auc:0.76860+0.01916
# [774]	train-auc:0.98652+0.00107	test-auc:0.76857+0.01910
# [775]	train-auc:0.98656+0.00105	test-auc:0.76854+0.01921
# [776]	train-auc:0.98660+0.00106	test-auc:0.76854+0.01909
# [777]	train-auc:0.98665+0.00108	test-auc:0.76867+0.01919
# [778]	train-auc:0.98670+0.00108	test-auc:0.76868+0.01937
# [779]	train-auc:0.98675+0.00105	test-auc:0.76860+0.01942
# [780]	train-auc:0.98677+0.00104	test-auc:0.76867+0.01938
# [781]	train-auc:0.98678+0.00102	test-auc:0.76864+0.01926
# [782]	train-auc:0.98681+0.00102	test-auc:0.76855+0.01950
# [783]	train-auc:0.98685+0.00101	test-auc:0.76851+0.01954
# [784]	train-auc:0.98687+0.00100	test-auc:0.76852+0.01957
# [785]	train-auc:0.98693+0.00102	test-auc:0.76859+0.01965
# [786]	train-auc:0.98697+0.00102	test-auc:0.76846+0.01979
# [787]	train-auc:0.98701+0.00102	test-auc:0.76823+0.01979
# [788]	train-auc:0.98703+0.00102	test-auc:0.76824+0.01959
# [789]	train-auc:0.98707+0.00103	test-auc:0.76821+0.01947
# [790]	train-auc:0.98708+0.00103	test-auc:0.76826+0.01948
# [791]	train-auc:0.98714+0.00103	test-auc:0.76834+0.01946
# [792]	train-auc:0.98716+0.00103	test-auc:0.76828+0.01942
# [793]	train-auc:0.98718+0.00104	test-auc:0.76835+0.01946
# [794]	train-auc:0.98720+0.00103	test-auc:0.76831+0.01956
# [795]	train-auc:0.98723+0.00104	test-auc:0.76839+0.01955
# [796]	train-auc:0.98725+0.00104	test-auc:0.76834+0.01952
# [797]	train-auc:0.98725+0.00104	test-auc:0.76844+0.01954
# [798]	train-auc:0.98727+0.00106	test-auc:0.76840+0.01965
# [799]	train-auc:0.98730+0.00106	test-auc:0.76840+0.01968
# [800]	train-auc:0.98731+0.00106	test-auc:0.76856+0.01978
# [801]	train-auc:0.98733+0.00107	test-auc:0.76866+0.01972
# [802]	train-auc:0.98735+0.00106	test-auc:0.76856+0.01979
# [803]	train-auc:0.98736+0.00105	test-auc:0.76857+0.01974
# [804]	train-auc:0.98739+0.00106	test-auc:0.76866+0.01971
# [805]	train-auc:0.98743+0.00103	test-auc:0.76875+0.01968
# [806]	train-auc:0.98746+0.00104	test-auc:0.76868+0.01971
# [807]	train-auc:0.98750+0.00103	test-auc:0.76868+0.01972
# [808]	train-auc:0.98753+0.00104	test-auc:0.76879+0.01964
# [809]	train-auc:0.98758+0.00105	test-auc:0.76867+0.01965
# [810]	train-auc:0.98758+0.00107	test-auc:0.76879+0.01973
# [811]	train-auc:0.98761+0.00102	test-auc:0.76870+0.01974
# Stopping. Best iteration:
# [712]	train-auc:0.98478+0.00111	test-auc:0.76990+0.02022

# %% [markdown]
# 得到结果为712

# %%
xgb1 = XGBClassifier(max_depth=5,
                     learning_rate=0.1,
                     n_estimators=712,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0,
                     min_child_weight=1,
                     subsample=0.8,
                     colsample_bytree=0.8,
                     seed=27)

# %% [markdown]
# 下面调整max_depth和min_child_weight参数

# %% [markdown]
# 首先先大范围粗调

# %%
param_grid = {'max_depth':range(1,9,2),
'min_child_weight':range(1,5,2)}
grid_search = GridSearchCV(xgb1,param_grid,scoring='f1',iid=False,cv=5)
grid_search.fit(x_train,y_train)
print('best_params:', grid_search.best_params_)
print('best_score:', grid_search.best_score_)
# Out:
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:19:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:19:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:19:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:19:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:19:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:19:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:19:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:19:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:19:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:19:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:19:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:19:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:19:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:19:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:19:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:19:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:20:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:20:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:20:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:20:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:20:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:20:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:20:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:20:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:20:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:20:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:20:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:20:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:21:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:21:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:21:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:21:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:21:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:21:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:21:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:21:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:21:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:22:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:22:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:22:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:847: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(
# [16:22:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# best_params: {'max_depth': 7, 'min_child_weight': 1}
# best_score: 0.21884645201651254

# %% [markdown]
# 下面再次对这两个参数进行细微调整

# %%
param_grid = {'max_depth':[6,7,8],
'min_child_weight':[0,1,2]}
grid_search = GridSearchCV(xgb1,param_grid,scoring='f1',iid=False,cv=5)
grid_search.fit(x_train,y_train)
print('best_params:', grid_search.best_params_)
print('best_score:', grid_search.best_score_)
# Out:
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:28:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:28:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:28:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:28:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:28:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:28:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:28:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:28:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:29:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:30:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:31:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:31:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:31:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:31:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:31:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:31:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:31:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:31:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:32:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:32:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:32:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:32:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:32:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:32:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:32:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:33:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:33:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:33:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:33:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:33:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:33:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:847: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(
# [16:33:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# best_params: {'max_depth': 8, 'min_child_weight': 0}
# best_score: 0.24610877865758782

# %% [markdown]
# 细化调整后得分有所提高，故采用max_depth=8，min_child_weight=0

# %%
xgb1 = XGBClassifier(max_depth=8,
                     learning_rate=0.1,
                     n_estimators=712,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0,
                     min_child_weight=0,
                     subsample=0.8,
                     colsample_bytree=0.8,
                     seed=27)

# %% [markdown]
# 下面继续调整gamma参数

# %%
param_grid = {'gamma':[i/10.0 for i in range(0,11)]}
grid_search = GridSearchCV(xgb1,param_grid,scoring='f1',iid=False,cv=5)
grid_search.fit(x_train,y_train)
print('best_params:', grid_search.best_params_)
print('best_score:', grid_search.best_score_)
# Out:
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:44:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:44:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:44:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:44:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:45:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:45:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:45:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:45:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:45:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:45:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:46:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:46:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:46:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:46:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:46:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:46:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:46:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:47:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:47:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:47:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:47:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:47:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:47:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:48:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:48:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:48:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:48:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:48:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:48:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:49:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:49:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:49:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:49:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:49:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:49:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:50:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:50:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:50:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:50:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:50:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:50:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:51:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:51:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:51:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:51:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:51:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:51:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:52:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:52:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:52:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:52:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:52:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:52:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:52:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:53:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:847: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(
# [16:53:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# best_params: {'gamma': 0.1}
# best_score: 0.24963431326754892

# %% [markdown]
# 得分提高，得到最佳gamma值为0.1

# %%
xgb1 = XGBClassifier(max_depth=8,
                     learning_rate=0.1,
                     n_estimators=712,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0.1,
                     min_child_weight=0,
                     subsample=0.8,
                     colsample_bytree=0.8,
                     seed=27)

# %% [markdown]
# 下面调整subsample和colsample_bytree参数

# %%
param_grid = {'subsample':[i/10.0 for i in range(6,11)],
'colsample_bytree':[i/10.0 for i in range(6,11)]}
grid_search = GridSearchCV(xgb1,param_grid,scoring='f1',iid=False,cv=5)
grid_search.fit(x_train,y_train)
print('best_params:', grid_search.best_params_)
print('best_score:', grid_search.best_score_)
# Out:
# Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:06:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:06:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:06:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:06:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:07:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:07:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:07:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:07:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:07:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:07:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:07:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:08:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:08:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:08:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:08:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:08:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:09:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:09:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:09:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:09:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:09:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:10:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:10:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:10:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:10:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:10:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:11:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:11:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:11:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:11:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:11:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:11:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:12:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:12:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:12:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:12:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:12:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:12:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:12:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:13:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:13:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:13:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:13:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:14:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:14:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:14:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:14:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:14:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:15:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:15:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:15:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:15:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:15:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:16:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:16:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:16:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:16:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:16:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:16:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:17:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:17:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:17:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:847: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(
# [17:17:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# best_params: {'colsample_bytree': 1.0, 'subsample': 0.6}
# best_score: 0.2581196763146104

# %% [markdown]
# 再进行细化的参数测试

# %%
param_grid = {'subsample':[i/10.0 for i in range(0,6)],
'colsample_bytree':[i/10.0 for i in range(8,11)]}
grid_search = GridSearchCV(xgb1,param_grid,scoring='f1',iid=False,cv=5)
grid_search.fit(x_train,y_train)
print('best_params:', grid_search.best_params_)
print('best_score:', grid_search.best_score_)
# Out:
# Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:49:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:50:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:50:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:50:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:50:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:50:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:50:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:50:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:50:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:50:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:50:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:51:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:51:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:51:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:51:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:51:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:51:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:51:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:52:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:52:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:52:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:52:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:52:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:53:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:53:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:53:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:53:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:54:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:54:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:54:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:54:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:54:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:55:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:55:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:55:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:55:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:55:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:55:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:55:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:55:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:55:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:55:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:56:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:56:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:56:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:56:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:56:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:56:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:57:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:57:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:57:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:57:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:58:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:58:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:58:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:58:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:58:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:59:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:59:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:59:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:59:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:00:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:847: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(
# [19:00:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# best_params: {'colsample_bytree': 1.0, 'subsample': 0.4}
# best_score: 0.2516351066294395

# %% [markdown]
# 得分降低，故选择上一次参数，colsample_bytree=1.0, subsample=0.6

# %%
xgb1 = XGBClassifier(max_depth=8,
                     learning_rate=0.1,
                     n_estimators=712,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0.1,
                     min_child_weight=0,
                     subsample=0.6,
                     colsample_bytree=1.0,
                     seed=27)

# %% [markdown]
# 最后尝试调整正则化参数

# %%
param_grid = {'reg_alpha':[i/10.0 for i in range(0,11)]}
grid_search = GridSearchCV(xgb1,param_grid,scoring='f1',iid=False,cv=5)
grid_search.fit(x_train,y_train)
print('best_params:', grid_search.best_params_)
print('best_score:', grid_search.best_score_)
# Out:
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:03:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:03:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:03:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:03:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:04:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:04:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:04:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:04:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:05:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:05:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:05:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:06:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:06:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:06:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:06:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:07:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:07:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:07:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:07:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:08:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:08:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:08:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:08:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:09:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:09:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:09:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:09:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:10:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:10:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:10:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:11:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:11:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:11:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:11:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:12:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:12:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:12:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:12:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:13:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:13:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:13:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:14:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:14:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:14:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:14:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:15:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:15:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:15:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:15:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:16:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:16:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:16:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:16:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:17:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:17:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:847: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(
# [19:17:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# best_params: {'reg_alpha': 0.0}
# best_score: 0.2581196763146104

# %% [markdown]
# 得分结果未改变，故不调整默认即可。

# %% [markdown]
# 继续尝试调整reg_lambda参数观察结果是否有提高

# %%
param_grid = {'reg_lambda':[i/10.0 for i in range(0,11)]}
grid_search = GridSearchCV(xgb1,param_grid,scoring='f1',iid=False,cv=5)
grid_search.fit(x_train,y_train)
print('best_params:', grid_search.best_params_)
print('best_score:', grid_search.best_score_)
# Out:
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:19:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:19:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:20:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:20:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:20:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:20:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:21:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:21:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:21:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:21:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:22:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:22:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:22:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:23:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:23:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:24:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:24:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:25:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:26:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:26:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:27:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:27:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:28:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:28:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:29:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:30:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:30:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:31:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:31:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:32:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:33:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:33:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:34:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:34:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:35:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:36:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:36:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:37:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:37:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:38:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:38:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:39:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:40:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:40:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:41:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:41:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:42:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:43:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:43:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:44:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:44:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:45:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:46:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:46:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:47:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# D:\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:847: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(
# [19:47:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# best_params: {'reg_lambda': 0.2}
# best_score: 0.2605130441438939

# %% [markdown]
# 得分提高故采用此参数reg_lambda=0.2

# %%
xgb1 = XGBClassifier(max_depth=8,
                     learning_rate=0.1,
                     n_estimators=712,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0.1,
                     min_child_weight=0,
                     subsample=0.6,
                     colsample_bytree=1.0,
                     reg_lambda=0.2,
                     seed=27)

# %%
#测试得分为
xgb_bst1 = xgb1.fit(x_train, y_train)
y_pred = xgb_bst1.predict(x_test)
y_pred2 = xgb_bst1.predict(x_train)
print("XGBoost结果")
print("balanced_accuracy_score=", balanced_accuracy_score(y_pred=y_pred, y_true=y_test),balanced_accuracy_score(y_pred=y_pred2, y_true=y_train))
print("f1=", f1_score(y_pred=y_pred, y_true=y_test), f1_score(y_pred=y_pred2, y_true=y_train))
print("precision_score=", precision_score(y_pred=y_pred, y_true=y_test),precision_score(y_pred=y_pred2, y_true=y_train))
print("recall_score=", recall_score(y_pred=y_pred, y_true=y_test), recall_score(y_pred=y_pred2, y_true=y_train))
print("accuracy=", accuracy_score(y_pred=y_pred, y_true=y_test), accuracy_score(y_pred=y_pred2, y_true=y_train))
print("auc=", roc_auc_score(y_true=y_test, y_score=y_pred), roc_auc_score(y_true=y_train, y_score=y_pred2))
print("#####混淆矩阵#########")
print(confusion_matrix(y_true=y_test, y_pred=y_pred), confusion_matrix(y_true=y_train, y_pred=y_pred2))
# Out:
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:42:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost结果
# balanced_accuracy_score= 0.6349857985242815 0.9786110427612693
# f1= 0.3878504672897196 0.9695670810115731
# precision_score= 0.6240601503759399 0.9809193408499567
# recall_score= 0.28135593220338984 0.9584745762711865
# accuracy= 0.9441007040751014 0.9962123232862097
# auc= 0.6349857985242815 0.9786110427612693
# #####混淆矩阵#########
# [[4342   50]
#  [ 212   83]] [[17543    22]
#  [   49  1131]]

# %% [markdown]
# 降低学习率，然后测试最佳迭代次数

# %%
xgb1 = XGBClassifier(max_depth=8,
                     learning_rate=0.05,
                     n_estimators=10000,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0.1,
                     min_child_weight=0,
                     subsample=0.6,
                     colsample_bytree=1.0,
                     reg_lambda=0.2,
                     seed=27)

# %%
cv_result = xgb.cv(xgb1.get_xgb_params(),
dtrain,
num_boost_round=xgb1.get_params()['n_estimators'],
nfold=5,
metrics='auc',
early_stopping_rounds=400,
callbacks=[xgb.callback.early_stop(400),
xgb.callback.print_evaluation(period=1,show_stdv=True)])
# Out:
# st-auc:0.78244+0.01057
# [416]	train-auc:0.99700+0.00028	test-auc:0.78240+0.01056
# [417]	train-auc:0.99701+0.00028	test-auc:0.78253+0.01064
# [418]	train-auc:0.99702+0.00028	test-auc:0.78240+0.01076
# [419]	train-auc:0.99704+0.00028	test-auc:0.78238+0.01066
# [420]	train-auc:0.99705+0.00027	test-auc:0.78231+0.01049
# [421]	train-auc:0.99708+0.00025	test-auc:0.78226+0.01038
# [422]	train-auc:0.99710+0.00025	test-auc:0.78231+0.01027
# [423]	train-auc:0.99712+0.00024	test-auc:0.78242+0.01045
# [424]	train-auc:0.99714+0.00022	test-auc:0.78248+0.01046
# [425]	train-auc:0.99716+0.00022	test-auc:0.78240+0.01023
# [426]	train-auc:0.99718+0.00021	test-auc:0.78249+0.01031
# [427]	train-auc:0.99720+0.00022	test-auc:0.78241+0.01019
# [428]	train-auc:0.99723+0.00022	test-auc:0.78232+0.01006
# [429]	train-auc:0.99724+0.00022	test-auc:0.78223+0.01027
# [430]	train-auc:0.99724+0.00020	test-auc:0.78213+0.01023
# [431]	train-auc:0.99727+0.00021	test-auc:0.78186+0.01022
# [432]	train-auc:0.99728+0.00021	test-auc:0.78179+0.01017
# [433]	train-auc:0.99729+0.00022	test-auc:0.78182+0.01005
# [434]	train-auc:0.99729+0.00022	test-auc:0.78194+0.01001
# [435]	train-auc:0.99732+0.00021	test-auc:0.78188+0.01004
# [436]	train-auc:0.99733+0.00022	test-auc:0.78187+0.00982
# [437]	train-auc:0.99733+0.00022	test-auc:0.78200+0.00971
# [438]	train-auc:0.99735+0.00022	test-auc:0.78203+0.00968
# [439]	train-auc:0.99736+0.00021	test-auc:0.78198+0.00998
# [440]	train-auc:0.99736+0.00023	test-auc:0.78195+0.01009
# [441]	train-auc:0.99737+0.00023	test-auc:0.78200+0.01000
# [442]	train-auc:0.99738+0.00022	test-auc:0.78198+0.01001
# [443]	train-auc:0.99739+0.00021	test-auc:0.78184+0.01011
# [444]	train-auc:0.99740+0.00020	test-auc:0.78177+0.01008
# [445]	train-auc:0.99742+0.00020	test-auc:0.78179+0.01003
# [446]	train-auc:0.99743+0.00020	test-auc:0.78177+0.00988
# [447]	train-auc:0.99745+0.00020	test-auc:0.78172+0.00988
# [448]	train-auc:0.99745+0.00020	test-auc:0.78189+0.00968
# [449]	train-auc:0.99746+0.00021	test-auc:0.78190+0.00961
# [450]	train-auc:0.99747+0.00021	test-auc:0.78171+0.00961
# [451]	train-auc:0.99747+0.00021	test-auc:0.78183+0.00975
# [452]	train-auc:0.99748+0.00020	test-auc:0.78165+0.00979
# [453]	train-auc:0.99750+0.00021	test-auc:0.78163+0.00959
# [454]	train-auc:0.99752+0.00023	test-auc:0.78176+0.00956
# [455]	train-auc:0.99753+0.00022	test-auc:0.78155+0.00974
# [456]	train-auc:0.99753+0.00022	test-auc:0.78157+0.00973
# [457]	train-auc:0.99754+0.00022	test-auc:0.78164+0.00989
# [458]	train-auc:0.99755+0.00023	test-auc:0.78177+0.01000
# [459]	train-auc:0.99755+0.00023	test-auc:0.78186+0.01012
# [460]	train-auc:0.99756+0.00021	test-auc:0.78194+0.01006
# [461]	train-auc:0.99757+0.00021	test-auc:0.78203+0.01006
# [462]	train-auc:0.99759+0.00019	test-auc:0.78195+0.01014
# [463]	train-auc:0.99761+0.00020	test-auc:0.78196+0.00992
# [464]	train-auc:0.99763+0.00020	test-auc:0.78184+0.01004
# [465]	train-auc:0.99764+0.00020	test-auc:0.78191+0.01014
# [466]	train-auc:0.99766+0.00019	test-auc:0.78185+0.01007
# [467]	train-auc:0.99766+0.00021	test-auc:0.78175+0.00995
# [468]	train-auc:0.99767+0.00020	test-auc:0.78167+0.00995
# [469]	train-auc:0.99769+0.00019	test-auc:0.78186+0.00999
# [470]	train-auc:0.99770+0.00019	test-auc:0.78182+0.00984
# [471]	train-auc:0.99771+0.00018	test-auc:0.78177+0.00999
# [472]	train-auc:0.99773+0.00018	test-auc:0.78175+0.00989
# [473]	train-auc:0.99774+0.00016	test-auc:0.78164+0.00982
# [474]	train-auc:0.99776+0.00016	test-auc:0.78174+0.00988
# [475]	train-auc:0.99776+0.00016	test-auc:0.78161+0.00995
# [476]	train-auc:0.99777+0.00016	test-auc:0.78173+0.01010
# [477]	train-auc:0.99779+0.00017	test-auc:0.78180+0.01004
# [478]	train-auc:0.99780+0.00016	test-auc:0.78177+0.01004
# [479]	train-auc:0.99781+0.00015	test-auc:0.78172+0.01010
# [480]	train-auc:0.99783+0.00015	test-auc:0.78171+0.01007
# [481]	train-auc:0.99783+0.00016	test-auc:0.78168+0.00991
# [482]	train-auc:0.99782+0.00017	test-auc:0.78175+0.00988
# [483]	train-auc:0.99783+0.00017	test-auc:0.78169+0.00991
# [484]	train-auc:0.99781+0.00016	test-auc:0.78162+0.00985
# [485]	train-auc:0.99781+0.00016	test-auc:0.78146+0.00978
# [486]	train-auc:0.99781+0.00016	test-auc:0.78152+0.00996
# [487]	train-auc:0.99782+0.00016	test-auc:0.78139+0.00989
# [488]	train-auc:0.99784+0.00016	test-auc:0.78150+0.00998
# [489]	train-auc:0.99785+0.00015	test-auc:0.78141+0.00996
# [490]	train-auc:0.99786+0.00015	test-auc:0.78144+0.00996
# [491]	train-auc:0.99788+0.00015	test-auc:0.78142+0.00994
# [492]	train-auc:0.99789+0.00015	test-auc:0.78134+0.00989
# [493]	train-auc:0.99790+0.00015	test-auc:0.78127+0.00994
# [494]	train-auc:0.99790+0.00016	test-auc:0.78109+0.00996
# [495]	train-auc:0.99790+0.00015	test-auc:0.78120+0.00990
# [496]	train-auc:0.99790+0.00016	test-auc:0.78133+0.00982
# [497]	train-auc:0.99792+0.00015	test-auc:0.78124+0.01002
# [498]	train-auc:0.99793+0.00015	test-auc:0.78122+0.00990
# [499]	train-auc:0.99794+0.00014	test-auc:0.78105+0.00996
# [500]	train-auc:0.99796+0.00015	test-auc:0.78088+0.00991
# [501]	train-auc:0.99795+0.00015	test-auc:0.78093+0.00990
# [502]	train-auc:0.99796+0.00016	test-auc:0.78088+0.00999
# [503]	train-auc:0.99798+0.00016	test-auc:0.78088+0.01005
# [504]	train-auc:0.99797+0.00015	test-auc:0.78087+0.01010
# [505]	train-auc:0.99798+0.00015	test-auc:0.78103+0.01019
# [506]	train-auc:0.99798+0.00015	test-auc:0.78097+0.01023
# [507]	train-auc:0.99799+0.00014	test-auc:0.78099+0.01032
# [508]	train-auc:0.99800+0.00015	test-auc:0.78108+0.01050
# [509]	train-auc:0.99802+0.00014	test-auc:0.78115+0.01043
# [510]	train-auc:0.99803+0.00015	test-auc:0.78109+0.01038
# [511]	train-auc:0.99803+0.00014	test-auc:0.78121+0.01038
# [512]	train-auc:0.99804+0.00014	test-auc:0.78124+0.01038
# [513]	train-auc:0.99805+0.00014	test-auc:0.78130+0.01034
# [514]	train-auc:0.99806+0.00014	test-auc:0.78137+0.01031
# [515]	train-auc:0.99806+0.00014	test-auc:0.78122+0.01029
# [516]	train-auc:0.99806+0.00014	test-auc:0.78124+0.01032
# [517]	train-auc:0.99807+0.00014	test-auc:0.78127+0.01030
# [518]	train-auc:0.99807+0.00015	test-auc:0.78130+0.01038
# [519]	train-auc:0.99808+0.00014	test-auc:0.78110+0.01036
# [520]	train-auc:0.99809+0.00015	test-auc:0.78121+0.01034
# [521]	train-auc:0.99809+0.00014	test-auc:0.78133+0.01025
# [522]	train-auc:0.99809+0.00013	test-auc:0.78133+0.01022
# [523]	train-auc:0.99810+0.00013	test-auc:0.78138+0.01020
# [524]	train-auc:0.99810+0.00014	test-auc:0.78160+0.01029
# [525]	train-auc:0.99811+0.00014	test-auc:0.78167+0.01036
# [526]	train-auc:0.99811+0.00014	test-auc:0.78176+0.01034
# [527]	train-auc:0.99813+0.00014	test-auc:0.78178+0.01032
# [528]	train-auc:0.99814+0.00014	test-auc:0.78166+0.01023
# [529]	train-auc:0.99815+0.00013	test-auc:0.78172+0.01011
# [530]	train-auc:0.99817+0.00014	test-auc:0.78174+0.01022
# [531]	train-auc:0.99817+0.00014	test-auc:0.78169+0.01033
# [532]	train-auc:0.99819+0.00015	test-auc:0.78173+0.01015
# [533]	train-auc:0.99819+0.00015	test-auc:0.78192+0.01025
# [534]	train-auc:0.99820+0.00016	test-auc:0.78200+0.01028
# [535]	train-auc:0.99821+0.00016	test-auc:0.78194+0.01028
# [536]	train-auc:0.99822+0.00017	test-auc:0.78182+0.01029
# [537]	train-auc:0.99822+0.00016	test-auc:0.78202+0.01029
# [538]	train-auc:0.99823+0.00017	test-auc:0.78195+0.01027
# [539]	train-auc:0.99824+0.00016	test-auc:0.78187+0.01032
# [540]	train-auc:0.99824+0.00016	test-auc:0.78187+0.01035
# [541]	train-auc:0.99825+0.00016	test-auc:0.78191+0.01042
# [542]	train-auc:0.99826+0.00016	test-auc:0.78191+0.01043
# [543]	train-auc:0.99828+0.00016	test-auc:0.78193+0.01059
# [544]	train-auc:0.99828+0.00014	test-auc:0.78199+0.01058
# [545]	train-auc:0.99827+0.00015	test-auc:0.78216+0.01063
# [546]	train-auc:0.99827+0.00015	test-auc:0.78216+0.01068
# [547]	train-auc:0.99828+0.00014	test-auc:0.78214+0.01069
# [548]	train-auc:0.99829+0.00015	test-auc:0.78207+0.01078
# [549]	train-auc:0.99830+0.00014	test-auc:0.78210+0.01078
# [550]	train-auc:0.99830+0.00014	test-auc:0.78211+0.01077
# [551]	train-auc:0.99831+0.00014	test-auc:0.78219+0.01072
# [552]	train-auc:0.99831+0.00014	test-auc:0.78222+0.01071
# [553]	train-auc:0.99832+0.00014	test-auc:0.78227+0.01097
# [554]	train-auc:0.99832+0.00014	test-auc:0.78228+0.01103
# [555]	train-auc:0.99833+0.00013	test-auc:0.78227+0.01098
# [556]	train-auc:0.99832+0.00015	test-auc:0.78234+0.01092
# [557]	train-auc:0.99832+0.00015	test-auc:0.78228+0.01088
# [558]	train-auc:0.99832+0.00016	test-auc:0.78223+0.01091
# [559]	train-auc:0.99834+0.00016	test-auc:0.78222+0.01069
# [560]	train-auc:0.99834+0.00016	test-auc:0.78216+0.01064
# [561]	train-auc:0.99835+0.00016	test-auc:0.78232+0.01067
# [562]	train-auc:0.99835+0.00016	test-auc:0.78240+0.01066
# [563]	train-auc:0.99835+0.00016	test-auc:0.78249+0.01083
# [564]	train-auc:0.99836+0.00016	test-auc:0.78246+0.01087
# [565]	train-auc:0.99836+0.00016	test-auc:0.78232+0.01084
# [566]	train-auc:0.99835+0.00017	test-auc:0.78239+0.01086
# [567]	train-auc:0.99836+0.00017	test-auc:0.78241+0.01080
# [568]	train-auc:0.99838+0.00017	test-auc:0.78229+0.01100
# [569]	train-auc:0.99837+0.00018	test-auc:0.78231+0.01097
# [570]	train-auc:0.99838+0.00017	test-auc:0.78215+0.01101
# [571]	train-auc:0.99839+0.00017	test-auc:0.78215+0.01099
# [572]	train-auc:0.99840+0.00017	test-auc:0.78221+0.01105
# [573]	train-auc:0.99840+0.00018	test-auc:0.78235+0.01108
# [574]	train-auc:0.99841+0.00018	test-auc:0.78219+0.01111
# [575]	train-auc:0.99841+0.00018	test-auc:0.78225+0.01100
# [576]	train-auc:0.99842+0.00019	test-auc:0.78217+0.01083
# [577]	train-auc:0.99842+0.00018	test-auc:0.78226+0.01113
# [578]	train-auc:0.99842+0.00018	test-auc:0.78229+0.01109
# [579]	train-auc:0.99843+0.00017	test-auc:0.78220+0.01110
# [580]	train-auc:0.99843+0.00017	test-auc:0.78214+0.01112
# [581]	train-auc:0.99843+0.00016	test-auc:0.78236+0.01119
# [582]	train-auc:0.99843+0.00016	test-auc:0.78240+0.01132
# [583]	train-auc:0.99843+0.00018	test-auc:0.78233+0.01132
# [584]	train-auc:0.99844+0.00018	test-auc:0.78227+0.01124
# [585]	train-auc:0.99845+0.00017	test-auc:0.78241+0.01128
# [586]	train-auc:0.99846+0.00016	test-auc:0.78242+0.01130
# [587]	train-auc:0.99845+0.00017	test-auc:0.78239+0.01118
# [588]	train-auc:0.99846+0.00017	test-auc:0.78212+0.01119
# [589]	train-auc:0.99847+0.00016	test-auc:0.78219+0.01131
# [590]	train-auc:0.99846+0.00016	test-auc:0.78225+0.01131
# [591]	train-auc:0.99847+0.00016	test-auc:0.78239+0.01115
# [592]	train-auc:0.99847+0.00017	test-auc:0.78235+0.01120
# [593]	train-auc:0.99848+0.00017	test-auc:0.78241+0.01110
# [594]	train-auc:0.99849+0.00017	test-auc:0.78247+0.01115
# [595]	train-auc:0.99849+0.00017	test-auc:0.78245+0.01123
# [596]	train-auc:0.99849+0.00017	test-auc:0.78258+0.01119
# [597]	train-auc:0.99849+0.00017	test-auc:0.78254+0.01117
# [598]	train-auc:0.99850+0.00018	test-auc:0.78260+0.01122
# [599]	train-auc:0.99851+0.00018	test-auc:0.78250+0.01120
# [600]	train-auc:0.99851+0.00017	test-auc:0.78243+0.01125
# [601]	train-auc:0.99852+0.00018	test-auc:0.78248+0.01119
# [602]	train-auc:0.99853+0.00017	test-auc:0.78254+0.01117
# [603]	train-auc:0.99853+0.00017	test-auc:0.78242+0.01118
# [604]	train-auc:0.99853+0.00017	test-auc:0.78230+0.01114
# [605]	train-auc:0.99855+0.00015	test-auc:0.78214+0.01130
# [606]	train-auc:0.99855+0.00015	test-auc:0.78209+0.01132
# [607]	train-auc:0.99854+0.00014	test-auc:0.78216+0.01130
# [608]	train-auc:0.99855+0.00015	test-auc:0.78217+0.01146
# [609]	train-auc:0.99855+0.00014	test-auc:0.78226+0.01134
# [610]	train-auc:0.99856+0.00014	test-auc:0.78230+0.01145
# [611]	train-auc:0.99856+0.00014	test-auc:0.78235+0.01145
# [612]	train-auc:0.99857+0.00013	test-auc:0.78221+0.01137
# [613]	train-auc:0.99856+0.00015	test-auc:0.78230+0.01131
# [614]	train-auc:0.99857+0.00014	test-auc:0.78232+0.01135
# [615]	train-auc:0.99857+0.00015	test-auc:0.78233+0.01142
# [616]	train-auc:0.99858+0.00015	test-auc:0.78218+0.01143
# [617]	train-auc:0.99858+0.00015	test-auc:0.78222+0.01152
# [618]	train-auc:0.99859+0.00015	test-auc:0.78229+0.01147
# [619]	train-auc:0.99859+0.00015	test-auc:0.78234+0.01151
# [620]	train-auc:0.99861+0.00015	test-auc:0.78230+0.01162
# [621]	train-auc:0.99862+0.00015	test-auc:0.78227+0.01167
# [622]	train-auc:0.99862+0.00015	test-auc:0.78221+0.01163
# [623]	train-auc:0.99862+0.00016	test-auc:0.78218+0.01148
# [624]	train-auc:0.99862+0.00015	test-auc:0.78215+0.01137
# [625]	train-auc:0.99863+0.00015	test-auc:0.78230+0.01129
# [626]	train-auc:0.99863+0.00015	test-auc:0.78236+0.01139
# [627]	train-auc:0.99864+0.00015	test-auc:0.78239+0.01135
# [628]	train-auc:0.99865+0.00015	test-auc:0.78222+0.01134
# [629]	train-auc:0.99865+0.00014	test-auc:0.78251+0.01141
# [630]	train-auc:0.99864+0.00014	test-auc:0.78241+0.01144
# [631]	train-auc:0.99865+0.00014	test-auc:0.78236+0.01142
# [632]	train-auc:0.99865+0.00015	test-auc:0.78242+0.01146
# [633]	train-auc:0.99865+0.00015	test-auc:0.78242+0.01137
# [634]	train-auc:0.99865+0.00015	test-auc:0.78231+0.01142
# [635]	train-auc:0.99866+0.00016	test-auc:0.78230+0.01139
# [636]	train-auc:0.99866+0.00016	test-auc:0.78227+0.01140
# [637]	train-auc:0.99867+0.00016	test-auc:0.78222+0.01134
# [638]	train-auc:0.99867+0.00015	test-auc:0.78225+0.01125
# [639]	train-auc:0.99868+0.00015	test-auc:0.78228+0.01130
# [640]	train-auc:0.99869+0.00014	test-auc:0.78237+0.01134
# [641]	train-auc:0.99869+0.00014	test-auc:0.78241+0.01140
# [642]	train-auc:0.99870+0.00014	test-auc:0.78233+0.01129
# [643]	train-auc:0.99872+0.00014	test-auc:0.78228+0.01131
# [644]	train-auc:0.99872+0.00015	test-auc:0.78226+0.01126
# [645]	train-auc:0.99873+0.00014	test-auc:0.78231+0.01136
# [646]	train-auc:0.99874+0.00013	test-auc:0.78237+0.01130
# [647]	train-auc:0.99875+0.00013	test-auc:0.78236+0.01115
# [648]	train-auc:0.99875+0.00013	test-auc:0.78240+0.01112
# [649]	train-auc:0.99875+0.00013	test-auc:0.78245+0.01107
# [650]	train-auc:0.99874+0.00013	test-auc:0.78248+0.01103
# [651]	train-auc:0.99874+0.00012	test-auc:0.78245+0.01108
# [652]	train-auc:0.99873+0.00012	test-auc:0.78248+0.01118
# [653]	train-auc:0.99874+0.00012	test-auc:0.78238+0.01106
# [654]	train-auc:0.99874+0.00012	test-auc:0.78248+0.01116
# [655]	train-auc:0.99876+0.00012	test-auc:0.78242+0.01116
# [656]	train-auc:0.99875+0.00013	test-auc:0.78247+0.01114
# [657]	train-auc:0.99876+0.00012	test-auc:0.78248+0.01119
# [658]	train-auc:0.99876+0.00012	test-auc:0.78256+0.01124
# [659]	train-auc:0.99877+0.00013	test-auc:0.78254+0.01137
# [660]	train-auc:0.99877+0.00012	test-auc:0.78261+0.01132
# [661]	train-auc:0.99877+0.00011	test-auc:0.78270+0.01124
# [662]	train-auc:0.99878+0.00012	test-auc:0.78263+0.01123
# [663]	train-auc:0.99878+0.00011	test-auc:0.78278+0.01136
# [664]	train-auc:0.99877+0.00011	test-auc:0.78285+0.01127
# [665]	train-auc:0.99877+0.00012	test-auc:0.78302+0.01133
# [666]	train-auc:0.99876+0.00012	test-auc:0.78293+0.01123
# [667]	train-auc:0.99876+0.00012	test-auc:0.78304+0.01120
# [668]	train-auc:0.99877+0.00013	test-auc:0.78312+0.01112
# [669]	train-auc:0.99877+0.00012	test-auc:0.78312+0.01108
# [670]	train-auc:0.99876+0.00013	test-auc:0.78315+0.01110
# [671]	train-auc:0.99876+0.00013	test-auc:0.78313+0.01098
# [672]	train-auc:0.99876+0.00013	test-auc:0.78320+0.01103
# [673]	train-auc:0.99877+0.00013	test-auc:0.78319+0.01095
# [674]	train-auc:0.99878+0.00012	test-auc:0.78328+0.01101
# [675]	train-auc:0.99877+0.00013	test-auc:0.78329+0.01080
# [676]	train-auc:0.99877+0.00013	test-auc:0.78318+0.01090
# [677]	train-auc:0.99878+0.00013	test-auc:0.78327+0.01088
# [678]	train-auc:0.99879+0.00013	test-auc:0.78329+0.01090
# [679]	train-auc:0.99880+0.00013	test-auc:0.78329+0.01099
# [680]	train-auc:0.99881+0.00012	test-auc:0.78315+0.01109
# [681]	train-auc:0.99882+0.00011	test-auc:0.78310+0.01104
# [682]	train-auc:0.99883+0.00011	test-auc:0.78295+0.01106
# [683]	train-auc:0.99883+0.00011	test-auc:0.78302+0.01113
# [684]	train-auc:0.99883+0.00012	test-auc:0.78299+0.01096
# [685]	train-auc:0.99883+0.00012	test-auc:0.78309+0.01099
# [686]	train-auc:0.99884+0.00012	test-auc:0.78295+0.01092
# [687]	train-auc:0.99883+0.00012	test-auc:0.78295+0.01087
# [688]	train-auc:0.99883+0.00011	test-auc:0.78296+0.01084
# [689]	train-auc:0.99884+0.00012	test-auc:0.78293+0.01076
# [690]	train-auc:0.99884+0.00012	test-auc:0.78296+0.01079
# [691]	train-auc:0.99884+0.00012	test-auc:0.78284+0.01065
# [692]	train-auc:0.99884+0.00012	test-auc:0.78281+0.01061
# [693]	train-auc:0.99885+0.00013	test-auc:0.78269+0.01061
# [694]	train-auc:0.99884+0.00012	test-auc:0.78280+0.01064
# [695]	train-auc:0.99884+0.00014	test-auc:0.78293+0.01067
# [696]	train-auc:0.99885+0.00014	test-auc:0.78297+0.01068
# [697]	train-auc:0.99884+0.00014	test-auc:0.78308+0.01075
# [698]	train-auc:0.99884+0.00014	test-auc:0.78307+0.01067
# [699]	train-auc:0.99884+0.00015	test-auc:0.78308+0.01061
# [700]	train-auc:0.99884+0.00014	test-auc:0.78317+0.01064
# [701]	train-auc:0.99885+0.00015	test-auc:0.78318+0.01072
# [702]	train-auc:0.99885+0.00014	test-auc:0.78312+0.01086
# [703]	train-auc:0.99885+0.00014	test-auc:0.78315+0.01076
# [704]	train-auc:0.99886+0.00013	test-auc:0.78305+0.01074
# [705]	train-auc:0.99887+0.00014	test-auc:0.78308+0.01079
# [706]	train-auc:0.99888+0.00012	test-auc:0.78326+0.01079
# [707]	train-auc:0.99887+0.00012	test-auc:0.78320+0.01088
# [708]	train-auc:0.99887+0.00012	test-auc:0.78336+0.01090
# [709]	train-auc:0.99888+0.00011	test-auc:0.78338+0.01093
# [710]	train-auc:0.99888+0.00012	test-auc:0.78328+0.01088
# [711]	train-auc:0.99887+0.00011	test-auc:0.78326+0.01101
# [712]	train-auc:0.99888+0.00010	test-auc:0.78324+0.01090
# [713]	train-auc:0.99887+0.00011	test-auc:0.78313+0.01095
# [714]	train-auc:0.99888+0.00012	test-auc:0.78315+0.01085
# [715]	train-auc:0.99889+0.00011	test-auc:0.78311+0.01090
# [716]	train-auc:0.99889+0.00011	test-auc:0.78307+0.01090
# [717]	train-auc:0.99889+0.00011	test-auc:0.78318+0.01088
# [718]	train-auc:0.99889+0.00011	test-auc:0.78319+0.01093
# [719]	train-auc:0.99889+0.00011	test-auc:0.78333+0.01094
# [720]	train-auc:0.99888+0.00012	test-auc:0.78331+0.01108
# [721]	train-auc:0.99889+0.00012	test-auc:0.78323+0.01102
# [722]	train-auc:0.99890+0.00011	test-auc:0.78330+0.01106
# [723]	train-auc:0.99890+0.00011	test-auc:0.78339+0.01106
# [724]	train-auc:0.99890+0.00011	test-auc:0.78333+0.01113
# [725]	train-auc:0.99890+0.00011	test-auc:0.78339+0.01114
# [726]	train-auc:0.99891+0.00011	test-auc:0.78339+0.01115
# [727]	train-auc:0.99891+0.00011	test-auc:0.78330+0.01115
# [728]	train-auc:0.99891+0.00012	test-auc:0.78326+0.01101
# [729]	train-auc:0.99891+0.00012	test-auc:0.78327+0.01091
# [730]	train-auc:0.99892+0.00013	test-auc:0.78316+0.01091
# [731]	train-auc:0.99893+0.00013	test-auc:0.78310+0.01087
# [732]	train-auc:0.99893+0.00012	test-auc:0.78313+0.01082
# [733]	train-auc:0.99893+0.00012	test-auc:0.78305+0.01085
# [734]	train-auc:0.99894+0.00012	test-auc:0.78300+0.01085
# [735]	train-auc:0.99894+0.00013	test-auc:0.78308+0.01085
# [736]	train-auc:0.99894+0.00013	test-auc:0.78320+0.01086
# [737]	train-auc:0.99894+0.00013	test-auc:0.78316+0.01080
# [738]	train-auc:0.99894+0.00014	test-auc:0.78330+0.01087
# [739]	train-auc:0.99894+0.00014	test-auc:0.78316+0.01083
# [740]	train-auc:0.99895+0.00014	test-auc:0.78323+0.01075
# [741]	train-auc:0.99895+0.00014	test-auc:0.78325+0.01079
# [742]	train-auc:0.99895+0.00014	test-auc:0.78335+0.01085
# [743]	train-auc:0.99896+0.00014	test-auc:0.78338+0.01087
# [744]	train-auc:0.99896+0.00014	test-auc:0.78338+0.01088
# [745]	train-auc:0.99896+0.00013	test-auc:0.78327+0.01094
# [746]	train-auc:0.99896+0.00013	test-auc:0.78334+0.01099
# [747]	train-auc:0.99896+0.00013	test-auc:0.78326+0.01107
# [748]	train-auc:0.99897+0.00013	test-auc:0.78322+0.01101
# [749]	train-auc:0.99898+0.00013	test-auc:0.78323+0.01109
# [750]	train-auc:0.99898+0.00013	test-auc:0.78332+0.01115
# [751]	train-auc:0.99899+0.00013	test-auc:0.78324+0.01118
# [752]	train-auc:0.99899+0.00013	test-auc:0.78322+0.01108
# [753]	train-auc:0.99899+0.00012	test-auc:0.78332+0.01110
# [754]	train-auc:0.99899+0.00012	test-auc:0.78335+0.01109
# [755]	train-auc:0.99900+0.00011	test-auc:0.78332+0.01116
# [756]	train-auc:0.99901+0.00011	test-auc:0.78317+0.01104
# [757]	train-auc:0.99901+0.00011	test-auc:0.78306+0.01102
# [758]	train-auc:0.99901+0.00011	test-auc:0.78312+0.01098
# [759]	train-auc:0.99901+0.00011	test-auc:0.78299+0.01104
# [760]	train-auc:0.99901+0.00012	test-auc:0.78300+0.01116
# [761]	train-auc:0.99902+0.00012	test-auc:0.78301+0.01113
# [762]	train-auc:0.99900+0.00013	test-auc:0.78306+0.01099
# [763]	train-auc:0.99900+0.00012	test-auc:0.78299+0.01110
# [764]	train-auc:0.99899+0.00012	test-auc:0.78311+0.01130
# Stopping. Best iteration:
# [365]	train-auc:0.99603+0.00040	test-auc:0.78340+0.01130

# %%
xgb1 = XGBClassifier(max_depth=8,
                     learning_rate=0.05,
                     n_estimators=365,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0.1,
                     min_child_weight=0,
                     subsample=0.6,
                     colsample_bytree=1.0,
                     reg_lambda=0.2,
                     seed=27)

# %%
#测试得分为
xgb_bst1 = xgb1.fit(x_train, y_train)
y_pred = xgb_bst1.predict(x_test)
y_pred2 = xgb_bst1.predict(x_train)
print("XGBoost结果")
print("balanced_accuracy_score=", balanced_accuracy_score(y_pred=y_pred, y_true=y_test),balanced_accuracy_score(y_pred=y_pred2, y_true=y_train))
print("f1=", f1_score(y_pred=y_pred, y_true=y_test), f1_score(y_pred=y_pred2, y_true=y_train))
print("precision_score=", precision_score(y_pred=y_pred, y_true=y_test),precision_score(y_pred=y_pred2, y_true=y_train))
print("recall_score=", recall_score(y_pred=y_pred, y_true=y_test), recall_score(y_pred=y_pred2, y_true=y_train))
print("accuracy=", accuracy_score(y_pred=y_pred, y_true=y_test), accuracy_score(y_pred=y_pred2, y_true=y_train))
print("auc=", roc_auc_score(y_true=y_test, y_score=y_pred), roc_auc_score(y_true=y_train, y_score=y_pred2))
print("#####混淆矩阵#########")
print(confusion_matrix(y_true=y_test, y_pred=y_pred), confusion_matrix(y_true=y_train, y_pred=y_pred2))
# Out:
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:46:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost结果
# balanced_accuracy_score= 0.5794205952270692 0.8057329434980002
# f1= 0.26666666666666666 0.7564169722367731
# precision_score= 0.7384615384615385 0.99039780521262
# recall_score= 0.16271186440677965 0.611864406779661
# accuracy= 0.9436739918924685 0.9751933849026407
# auc= 0.5794205952270692 0.8057329434980002
# #####混淆矩阵#########
# [[4375   17]
#  [ 247   48]] [[17558     7]
#  [  458   722]]

# %% [markdown]
# 继续调低学习率

# %%
xgb1 = XGBClassifier(max_depth=8,
                     learning_rate=0.025,
                     n_estimators=10000,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0.1,
                     min_child_weight=0,
                     subsample=0.6,
                     colsample_bytree=1.0,
                     reg_lambda=0.2,
                     seed=27)

# %%
cv_result = xgb.cv(xgb1.get_xgb_params(),
dtrain,
num_boost_round=xgb1.get_params()['n_estimators'],
nfold=5,
metrics='auc',
early_stopping_rounds=400)

# %%
print(cv_result.shape[0])
# Out:
# 548

# %%
xgb1 = XGBClassifier(max_depth=8,
                     learning_rate=0.025,
                     n_estimators=548,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0.1,
                     min_child_weight=0,
                     subsample=0.6,
                     colsample_bytree=1.0,
                     reg_lambda=0.2,
                     seed=27)

# %%
#测试得分为
xgb_bst1 = xgb1.fit(x_train, y_train)
y_pred = xgb_bst1.predict(x_test)
y_pred2 = xgb_bst1.predict(x_train)
print("XGBoost结果")
print("balanced_accuracy_score=", balanced_accuracy_score(y_pred=y_pred, y_true=y_test),balanced_accuracy_score(y_pred=y_pred2, y_true=y_train))
print("f1=", f1_score(y_pred=y_pred, y_true=y_test), f1_score(y_pred=y_pred2, y_true=y_train))
print("precision_score=", precision_score(y_pred=y_pred, y_true=y_test),precision_score(y_pred=y_pred2, y_true=y_train))
print("recall_score=", recall_score(y_pred=y_pred, y_true=y_test), recall_score(y_pred=y_pred2, y_true=y_train))
print("accuracy=", accuracy_score(y_pred=y_pred, y_true=y_test), accuracy_score(y_pred=y_pred2, y_true=y_train))
print("auc=", roc_auc_score(y_true=y_test, y_score=y_pred), roc_auc_score(y_true=y_train, y_score=y_pred2))
print("#####混淆矩阵#########")
print(confusion_matrix(y_true=y_test, y_pred=y_pred), confusion_matrix(y_true=y_train, y_pred=y_pred2))
# Out:
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:56:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost结果
# balanced_accuracy_score= 0.5577282269766293 0.7371458070990559
# f1= 0.20348837209302328 0.6418338108882522
# precision_score= 0.7142857142857143 0.9911504424778761
# recall_score= 0.11864406779661017 0.4745762711864407
# accuracy= 0.9415404309793045 0.9666577754067751
# auc= 0.5577282269766293 0.7371458070990559
# #####混淆矩阵#########
# [[4378   14]
#  [ 260   35]] [[17560     5]
#  [  620   560]]

# %% [markdown]
# 继续降低学习率测试

# %%
xgb1 = XGBClassifier(max_depth=8,
                     learning_rate=0.015,
                     n_estimators=10000,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0.1,
                     min_child_weight=0,
                     subsample=0.6,
                     colsample_bytree=1.0,
                     reg_lambda=0.2,
                     seed=27)

# %%
cv_result = xgb.cv(xgb1.get_xgb_params(),
dtrain,
num_boost_round=xgb1.get_params()['n_estimators'],
nfold=5,
metrics='auc',
early_stopping_rounds=400)
print(cv_result.shape[0])
# Out:
# 810

# %%
xgb1 = XGBClassifier(max_depth=8,
                     learning_rate=0.015,
                     n_estimators=810,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0.1,
                     min_child_weight=0,
                     subsample=0.6,
                     colsample_bytree=1.0,
                     reg_lambda=0.2,
                     seed=27)

# %%
#测试得分为
xgb_bst1 = xgb1.fit(x_train, y_train)
y_pred = xgb_bst1.predict(x_test)
y_pred2 = xgb_bst1.predict(x_train)
print("XGBoost结果")
print("balanced_accuracy_score=", balanced_accuracy_score(y_pred=y_pred, y_true=y_test),balanced_accuracy_score(y_pred=y_pred2, y_true=y_train))
print("f1=", f1_score(y_pred=y_pred, y_true=y_test), f1_score(y_pred=y_pred2, y_true=y_train))
print("precision_score=", precision_score(y_pred=y_pred, y_true=y_test),precision_score(y_pred=y_pred2, y_true=y_train))
print("recall_score=", recall_score(y_pred=y_pred, y_true=y_test), recall_score(y_pred=y_pred2, y_true=y_train))
print("accuracy=", accuracy_score(y_pred=y_pred, y_true=y_test), accuracy_score(y_pred=y_pred2, y_true=y_train))
print("auc=", roc_auc_score(y_true=y_test, y_score=y_pred), roc_auc_score(y_true=y_train, y_score=y_pred2))
print("#####混淆矩阵#########")
print(confusion_matrix(y_true=y_test, y_pred=y_pred), confusion_matrix(y_true=y_train, y_pred=y_pred2))
# Out:
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:59:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost结果
# balanced_accuracy_score= 0.5525296378623692 0.708303782078189
# f1= 0.18713450292397663 0.5864123957091776
# precision_score= 0.6808510638297872 0.9879518072289156
# recall_score= 0.10847457627118644 0.41694915254237286
# accuracy= 0.9406870066140388 0.9629767938116831
# auc= 0.5525296378623692 0.7083037820781889
# #####混淆矩阵#########
# [[4377   15]
#  [ 263   32]] [[17559     6]
#  [  688   492]]

# %% [markdown]
# 继续降低学习率

# %%
xgb1 = XGBClassifier(max_depth=8,
                     learning_rate=0.01,
                     n_estimators=10000,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0.1,
                     min_child_weight=0,
                     subsample=0.6,
                     colsample_bytree=1.0,
                     reg_lambda=0.2,
                     seed=27)

# %%
cv_result = xgb.cv(xgb1.get_xgb_params(),
dtrain,
num_boost_round=xgb1.get_params()['n_estimators'],
nfold=5,
metrics='auc',
early_stopping_rounds=400)
print(cv_result.shape[0])
# Out:
# 872

# %%
xgb1 = XGBClassifier(max_depth=8,
                     learning_rate=0.01,
                     n_estimators=872,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0.1,
                     min_child_weight=0,
                     subsample=0.6,
                     colsample_bytree=1.0,
                     reg_lambda=0.2,
                     seed=27)

# %%
#测试得分为
xgb_bst1 = xgb1.fit(x_train, y_train)
y_pred = xgb_bst1.predict(x_test)
y_pred2 = xgb_bst1.predict(x_train)
print("XGBoost结果")
print("balanced_accuracy_score=", balanced_accuracy_score(y_pred=y_pred, y_true=y_test),balanced_accuracy_score(y_pred=y_pred2, y_true=y_train))
print("f1=", f1_score(y_pred=y_pred, y_true=y_test), f1_score(y_pred=y_pred2, y_true=y_train))
print("precision_score=", precision_score(y_pred=y_pred, y_true=y_test),precision_score(y_pred=y_pred2, y_true=y_train))
print("recall_score=", recall_score(y_pred=y_pred, y_true=y_test), recall_score(y_pred=y_pred2, y_true=y_train))
print("accuracy=", accuracy_score(y_pred=y_pred, y_true=y_test), accuracy_score(y_pred=y_pred2, y_true=y_train))
print("auc=", roc_auc_score(y_true=y_test, y_score=y_pred), roc_auc_score(y_true=y_train, y_score=y_pred2))
print("#####混淆矩阵#########")
print(confusion_matrix(y_true=y_test, y_pred=y_pred), confusion_matrix(y_true=y_train, y_pred=y_pred2))
# Out:
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [22:02:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost结果
# balanced_accuracy_score= 0.5293700410607884 0.6379932647261745
# f1= 0.11145510835913312 0.43150231634679015
# precision_score= 0.6428571428571429 0.9848942598187311
# recall_score= 0.061016949152542375 0.27627118644067794
# accuracy= 0.9387668017921912 0.9541744465190718
# auc= 0.5293700410607884 0.6379932647261745
# #####混淆矩阵#########
# [[4382   10]
#  [ 277   18]] [[17560     5]
#  [  854   326]]

# %% [markdown]
# 手动调整学习率和迭代次数

# %%
xgb1 = XGBClassifier(max_depth=8,
                     learning_rate=0.05,
                     n_estimators=7250,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0.1,
                     min_child_weight=0,
                     subsample=0.6,
                     colsample_bytree=1.0,
                     reg_lambda=0.2,
                     seed=27)

# %%
#测试得分为
xgb_bst1 = xgb1.fit(x_train, y_train)
y_pred = xgb_bst1.predict(x_test)
y_pred2 = xgb_bst1.predict(x_train)
print("XGBoost结果")
print("balanced_accuracy_score=", balanced_accuracy_score(y_pred=y_pred, y_true=y_test),balanced_accuracy_score(y_pred=y_pred2, y_true=y_train))
print("f1=", f1_score(y_pred=y_pred, y_true=y_test), f1_score(y_pred=y_pred2, y_true=y_train))
print("precision_score=", precision_score(y_pred=y_pred, y_true=y_test),precision_score(y_pred=y_pred2, y_true=y_train))
print("recall_score=", recall_score(y_pred=y_pred, y_true=y_test), recall_score(y_pred=y_pred2, y_true=y_train))
print("accuracy=", accuracy_score(y_pred=y_pred, y_true=y_test), accuracy_score(y_pred=y_pred2, y_true=y_train))
print("auc=", roc_auc_score(y_true=y_test, y_score=y_pred), roc_auc_score(y_true=y_train, y_score=y_pred2))
print("#####混淆矩阵#########")
print(confusion_matrix(y_true=y_test, y_pred=y_pred), confusion_matrix(y_true=y_train, y_pred=y_pred2))
# Out:
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [22:46:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost结果
# balanced_accuracy_score= 0.6615352258343367 0.9814917473596858
# f1= 0.4409799554565702 0.9714041826717882
# precision_score= 0.6428571428571429 0.9785038693035254
# recall_score= 0.33559322033898303 0.964406779661017
# accuracy= 0.9464476210795818 0.9964257135236063
# auc= 0.6615352258343368 0.9814917473596858
# #####混淆矩阵#########
# [[4337   55]
#  [ 196   99]] [[17540    25]
#  [   42  1138]]

# %%
xgb1 = XGBClassifier(max_depth=8,
                     learning_rate=0.1,
                     n_estimators=1350,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0.1,
                     min_child_weight=0,
                     subsample=0.6,
                     colsample_bytree=1.0,
                     reg_lambda=0.2,
                     seed=27)

# %%
#测试得分为
xgb_bst1 = xgb1.fit(x_train, y_train)
y_pred = xgb_bst1.predict(x_test)
y_pred2 = xgb_bst1.predict(x_train)
print("XGBoost结果")
print("balanced_accuracy_score=", balanced_accuracy_score(y_pred=y_pred, y_true=y_test),balanced_accuracy_score(y_pred=y_pred2, y_true=y_train))
print("f1=", f1_score(y_pred=y_pred, y_true=y_test), f1_score(y_pred=y_pred2, y_true=y_train))
print("precision_score=", precision_score(y_pred=y_pred, y_true=y_test),precision_score(y_pred=y_pred2, y_true=y_train))
print("recall_score=", recall_score(y_pred=y_pred, y_true=y_test), recall_score(y_pred=y_pred2, y_true=y_train))
print("accuracy=", accuracy_score(y_pred=y_pred, y_true=y_test), accuracy_score(y_pred=y_pred2, y_true=y_train))
print("auc=", roc_auc_score(y_true=y_test, y_score=y_pred), roc_auc_score(y_true=y_train, y_score=y_pred2))
print("#####混淆矩阵#########")
print(confusion_matrix(y_true=y_test, y_pred=y_pred), confusion_matrix(y_true=y_train, y_pred=y_pred2))
# Out:
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [22:56:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost结果
# balanced_accuracy_score= 0.6463948318977494 0.9838633260480443
# f1= 0.4100227790432802 0.9715498938428875
# precision_score= 0.625 0.9736170212765958
# recall_score= 0.3050847457627119 0.9694915254237289
# accuracy= 0.9447407723490505 0.9964257135236063
# auc= 0.6463948318977494 0.9838633260480443
# #####混淆矩阵#########
# [[4338   54]
#  [ 205   90]] [[17534    31]
#  [   36  1144]]

# %%
xgb1 = XGBClassifier(max_depth=8,
                     learning_rate=0.01,
                     n_estimators=14000,
                     objective='binary:logistic',
                     booster='gbtree',
                     n_jobs=4,
                     gamma=0.1,
                     min_child_weight=0,
                     subsample=0.6,
                     colsample_bytree=1.0,
                     reg_lambda=0.2,
                     seed=27)

# %%
#测试得分为
xgb_bst1 = xgb1.fit(x_train, y_train)
y_pred = xgb_bst1.predict(x_test)
y_pred2 = xgb_bst1.predict(x_train)
print("XGBoost结果")
print("balanced_accuracy_score=", balanced_accuracy_score(y_pred=y_pred, y_true=y_test),balanced_accuracy_score(y_pred=y_pred2, y_true=y_train))
print("f1=", f1_score(y_pred=y_pred, y_true=y_test), f1_score(y_pred=y_pred2, y_true=y_train))
print("precision_score=", precision_score(y_pred=y_pred, y_true=y_test),precision_score(y_pred=y_pred2, y_true=y_train))
print("recall_score=", recall_score(y_pred=y_pred, y_true=y_test), recall_score(y_pred=y_pred2, y_true=y_train))
print("accuracy=", accuracy_score(y_pred=y_pred, y_true=y_test), accuracy_score(y_pred=y_pred2, y_true=y_train))
print("auc=", roc_auc_score(y_true=y_test, y_score=y_pred), roc_auc_score(y_true=y_train, y_score=y_pred2))
print("#####混淆矩阵#########")
print(confusion_matrix(y_true=y_test, y_pred=y_pred), confusion_matrix(y_true=y_train, y_pred=y_pred2))
# Out:
# D:\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [23:03:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBoost结果
# balanced_accuracy_score= 0.6438019048501127 0.9818870104744122
# f1= 0.4093023255813954 0.9714285714285714
# precision_score= 0.6518518518518519 0.9776824034334763
# recall_score= 0.2983050847457627 0.9652542372881356
# accuracy= 0.9458075528056326 0.9964257135236063
# auc= 0.6438019048501127 0.9818870104744122
# #####混淆矩阵#########
# [[4345   47]
#  [ 207   88]] [[17539    26]
#  [   41  1139]]
