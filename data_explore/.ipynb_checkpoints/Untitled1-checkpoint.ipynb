# %%
#特征选择已经结束，依据新的数据集进行验证与找出最优模型
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
% matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import gc
from collections import Counter
import copy
from sklearn.preprocessing import StandardScaler
from collections import Counter


def minmax_target(x_train, x_test, y_train):
    import category_encoders as ce
    encoder = ce.TargetEncoder(cols=discrete_list, drop_invariant=False).fit(x_train, y_train)
    x_train = encoder.transform(x_train)  # 基于训练集得到编码器
    x_test = encoder.transform(x_test)

    std = StandardScaler()
    X_train[continue_list] = std.fit_transform(X_train[continue_list])
    X_test[continue_list] = std.transform(X_test[continue_list])

    return x_train, x_test


def read_csv(file_name, num_rows):
    return pd.read_csv(file_name, nrows=num_rows)


def reduce_mem_usage(df, verbose=True):
    start_mem = df.memory_usage().sum() / 1024 ** 2
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)

    end_mem = df.memory_usage().sum() / 1024 ** 2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    return df


train = reduce_mem_usage(pd.read_csv("D:/2021软件服务外包比赛/result/" + 'train_choose.csv'))
test = reduce_mem_usage(pd.read_csv("D:/2021软件服务外包比赛/result/" + 'test_choose.csv'))
X_train = train.drop(['emd_lable2'], axis=1)
X_test = test.drop(['emd_lable2'], axis=1)
y_train = train['emd_lable2'].to_numpy()
y_test = test['emd_lable2'].to_numpy()
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
print(Counter(y_train), Counter(y_test))  # 比较训练集与测试集的分布情况

feature_list = list(X_train.columns.array)
discrete_list = ['pax_name', 'pax_passport', 'pref_orig_y3_3', 'seg_dep_time']
continue_list = list(set(feature_list) - set(discrete_list))
X_train, X_test = minmax_target(X_train, X_test, y_train)
# Out:
# Memory usage after optimization is: 1.68 MB
# Decreased by 48.9%
# Memory usage after optimization is: 0.42 MB
# Decreased by 48.9%
# (18745, 22) (4687, 22) (18745,) (4687,)
# Counter({0: 17565, 1: 1180}) Counter({0: 4392, 1: 295})

# %%
#随机森林的实验——》全都预测为0了好像，过拟合非常严重啊
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

dTree = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=0, n_jobs=-1)
dTree.fit(X_train, y_train)
y_pred = dTree.predict(X_test)
from sklearn.metrics import balanced_accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
print("balanced_accuracy_score=", balanced_accuracy_score(y_pred=y_pred, y_true=y_test))
print("f1=", f1_score(y_pred=y_pred, y_true=y_test))
print("precision_score=", precision_score(y_pred=y_pred, y_true=y_test))
print("recall_score=", recall_score(y_pred=y_pred, y_true=y_test))
print("auc=", roc_auc_score(y_true=y_test, y_score=dTree.predict_proba(X_test)[:, 1]))
# Out:
# balanced_accuracy_score= 0.5
# f1= 0.0
# precision_score= 0.0
# recall_score= 0.0
# auc= 0.7732275169028433

# %%
#随机森林调参
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier



# model 
clf = RandomForestClassifier(n_jobs=-1)

# Set the parameters by cross-validation

tuned_parameters = {
                    'n_estimators': [50, 100, 200]
                    ,'criterion': ['gini', 'entropy']
                    ,'max_depth': [2, 5]
                    ,'max_features': ['log2', 'sqrt', 'int']
                    ,'bootstrap': [True, False]
                    ,'warm_start': [True, False]
                    }

scores = ['f1']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(clf, tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for f1
#
# Best parameters set found on development set:
#
# {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
#
# Grid scores on development set:
#
# 0.496 (+/-0.033) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': True}
# 0.509 (+/-0.078) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': False}
# 0.505 (+/-0.036) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': True}
# 0.513 (+/-0.040) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': False}
# 0.517 (+/-0.058) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': True}
# 0.505 (+/-0.040) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': False}
# 0.504 (+/-0.047) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': True}
# 0.518 (+/-0.038) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
# 0.511 (+/-0.030) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': True}
# 0.504 (+/-0.024) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': False}
# 0.511 (+/-0.023) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': True}
# 0.528 (+/-0.021) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 50, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 50, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 100, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 100, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 200, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 200, 'warm_start': False}
# 0.628 (+/-0.047) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': True}
# 0.619 (+/-0.036) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': False}
# 0.627 (+/-0.044) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': True}
# 0.623 (+/-0.049) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': False}
# 0.625 (+/-0.037) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': True}
# 0.626 (+/-0.048) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': False}
# 0.626 (+/-0.048) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': True}
# 0.622 (+/-0.051) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
# 0.621 (+/-0.047) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': True}
# 0.620 (+/-0.040) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': False}
# 0.628 (+/-0.049) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': True}
# 0.627 (+/-0.047) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 50, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 50, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 100, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 100, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 200, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 200, 'warm_start': False}
# 0.484 (+/-0.000) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': True}
# 0.493 (+/-0.023) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': False}
# 0.500 (+/-0.040) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': True}
# 0.494 (+/-0.029) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': False}
# 0.485 (+/-0.004) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': True}
# 0.484 (+/-0.000) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': False}
# 0.485 (+/-0.007) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': True}
# 0.508 (+/-0.039) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
# 0.504 (+/-0.042) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': True}
# 0.511 (+/-0.057) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': False}
# 0.484 (+/-0.000) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': True}
# 0.484 (+/-0.000) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 50, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 50, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 100, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 100, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 200, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 200, 'warm_start': False}
# 0.615 (+/-0.041) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': True}
# 0.626 (+/-0.021) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': False}
# 0.620 (+/-0.044) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': True}
# 0.614 (+/-0.054) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': False}
# 0.616 (+/-0.048) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': True}
# 0.613 (+/-0.058) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': False}
# 0.614 (+/-0.052) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': True}
# 0.618 (+/-0.049) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
# 0.619 (+/-0.052) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': True}
# 0.609 (+/-0.054) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': False}
# 0.614 (+/-0.041) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': True}
# 0.618 (+/-0.051) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 50, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 50, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 100, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 100, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 200, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 200, 'warm_start': False}
# 0.523 (+/-0.051) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': True}
# 0.516 (+/-0.047) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': False}
# 0.508 (+/-0.068) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': True}
# 0.515 (+/-0.043) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': False}
# 0.503 (+/-0.032) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': True}
# 0.507 (+/-0.054) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': False}
# 0.510 (+/-0.077) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': True}
# 0.519 (+/-0.040) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
# 0.501 (+/-0.055) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': True}
# 0.501 (+/-0.020) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': False}
# 0.512 (+/-0.046) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': True}
# 0.502 (+/-0.028) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 50, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 50, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 100, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 100, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 200, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 200, 'warm_start': False}
# 0.622 (+/-0.058) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': True}
# 0.620 (+/-0.054) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': False}
# 0.621 (+/-0.041) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': True}
# 0.628 (+/-0.041) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': False}
# 0.627 (+/-0.036) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': True}
# 0.627 (+/-0.047) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': False}
# 0.626 (+/-0.043) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': True}
# 0.636 (+/-0.033) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
# 0.626 (+/-0.040) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': True}
# 0.629 (+/-0.038) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': False}
# 0.624 (+/-0.053) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': True}
# 0.627 (+/-0.045) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 50, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 50, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 100, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 100, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 200, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 200, 'warm_start': False}
# 0.498 (+/-0.044) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': True}
# 0.484 (+/-0.000) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': False}
# 0.485 (+/-0.003) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': True}
# 0.513 (+/-0.059) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': False}
# 0.484 (+/-0.000) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': True}
# 0.492 (+/-0.029) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': False}
# 0.489 (+/-0.020) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': True}
# 0.497 (+/-0.055) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
# 0.494 (+/-0.029) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': True}
# 0.493 (+/-0.036) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': False}
# 0.498 (+/-0.058) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': True}
# 0.484 (+/-0.000) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 50, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 50, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 100, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 100, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 200, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 200, 'warm_start': False}
# 0.619 (+/-0.059) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': True}
# 0.612 (+/-0.049) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': False}
# 0.615 (+/-0.045) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': True}
# 0.610 (+/-0.057) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': False}
# 0.619 (+/-0.061) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': True}
# 0.609 (+/-0.056) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': False}
# 0.621 (+/-0.049) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': True}
# 0.608 (+/-0.049) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
# 0.616 (+/-0.037) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': True}
# 0.609 (+/-0.044) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': False}
# 0.613 (+/-0.048) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': True}
# 0.617 (+/-0.052) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 50, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 50, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 100, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 100, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 200, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 200, 'warm_start': False}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      4392
#            1       0.53      0.03      0.05       295
#
#     accuracy                           0.94      4687
#    macro avg       0.74      0.51      0.51      4687
# weighted avg       0.91      0.94      0.91      4687

# %%
#过拟合非常严重，使用不平衡数据集的处理方法！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！！
from imblearn.over_sampling import SMOTE

smo = SMOTE(random_state=0)
X_train, y_train = smo.fit_sample(X_train, y_train)
print(Counter(y_train))
# Out:
# Counter({0: 17565, 1: 17565})

# %%
#随机森林调参——》使用平衡数据集后效果有所改善！
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier



# model 
clf = RandomForestClassifier(n_jobs=-1)

# Set the parameters by cross-validation

tuned_parameters = {
                    'n_estimators': [20 , 50, 100, 200]
                    ,'criterion': ['gini', 'entropy']
                    ,'max_depth': [3,5,10]
                    ,'max_features': ['log2', 'sqrt', 'int']
                    ,'bootstrap': [True, False]
                    ,'warm_start': [True, False]
                    }

scores = ['f1']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(clf, tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for f1
#
# Best parameters set found on development set:
#
# {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
#
# Grid scores on development set:
#
# 0.927 (+/-0.037) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': True}
# 0.924 (+/-0.036) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': False}
# 0.927 (+/-0.035) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': True}
# 0.927 (+/-0.035) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': False}
# 0.925 (+/-0.034) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': True}
# 0.923 (+/-0.032) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': False}
# 0.927 (+/-0.033) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': True}
# 0.925 (+/-0.033) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
# 0.926 (+/-0.026) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': True}
# 0.925 (+/-0.036) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': False}
# 0.925 (+/-0.034) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': True}
# 0.924 (+/-0.036) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 50, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 50, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 100, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 100, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 200, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 200, 'warm_start': False}
# 0.937 (+/-0.029) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': True}
# 0.936 (+/-0.031) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': False}
# 0.936 (+/-0.029) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': True}
# 0.937 (+/-0.030) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': False}
# 0.937 (+/-0.030) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': True}
# 0.937 (+/-0.032) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': False}
# 0.935 (+/-0.030) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': True}
# 0.937 (+/-0.031) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
# 0.936 (+/-0.032) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': True}
# 0.936 (+/-0.032) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': False}
# 0.937 (+/-0.029) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': True}
# 0.937 (+/-0.029) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 50, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 50, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 100, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 100, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 200, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 200, 'warm_start': False}
# 0.922 (+/-0.034) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': True}
# 0.924 (+/-0.033) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': False}
# 0.923 (+/-0.033) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': True}
# 0.926 (+/-0.036) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': False}
# 0.923 (+/-0.032) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': True}
# 0.924 (+/-0.031) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': False}
# 0.923 (+/-0.032) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': True}
# 0.922 (+/-0.032) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
# 0.923 (+/-0.033) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': True}
# 0.923 (+/-0.034) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': False}
# 0.923 (+/-0.033) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': True}
# 0.924 (+/-0.033) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 50, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 50, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 100, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 100, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 200, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 200, 'warm_start': False}
# 0.935 (+/-0.028) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': True}
# 0.934 (+/-0.031) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': False}
# 0.936 (+/-0.031) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': True}
# 0.937 (+/-0.030) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': False}
# 0.935 (+/-0.031) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': True}
# 0.936 (+/-0.029) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': False}
# 0.936 (+/-0.033) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': True}
# 0.935 (+/-0.028) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
# 0.935 (+/-0.033) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': True}
# 0.936 (+/-0.028) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': False}
# 0.935 (+/-0.029) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': True}
# 0.935 (+/-0.029) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 50, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 50, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 100, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 100, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 200, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 200, 'warm_start': False}
# 0.925 (+/-0.028) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': True}
# 0.922 (+/-0.031) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': False}
# 0.924 (+/-0.033) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': True}
# 0.926 (+/-0.032) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': False}
# 0.925 (+/-0.032) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': True}
# 0.925 (+/-0.034) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': False}
# 0.926 (+/-0.034) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': True}
# 0.925 (+/-0.032) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
# 0.926 (+/-0.033) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': True}
# 0.925 (+/-0.032) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': False}
# 0.925 (+/-0.033) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': True}
# 0.926 (+/-0.032) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 50, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 50, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 100, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 100, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 200, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 200, 'warm_start': False}
# 0.937 (+/-0.030) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': True}
# 0.937 (+/-0.031) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': False}
# 0.935 (+/-0.031) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': True}
# 0.936 (+/-0.031) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': False}
# 0.937 (+/-0.030) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': True}
# 0.936 (+/-0.029) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': False}
# 0.937 (+/-0.030) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': True}
# 0.938 (+/-0.027) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
# 0.937 (+/-0.029) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': True}
# 0.937 (+/-0.029) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': False}
# 0.937 (+/-0.029) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': True}
# 0.937 (+/-0.031) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 50, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 50, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 100, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 100, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 200, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 200, 'warm_start': False}
# 0.922 (+/-0.031) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': True}
# 0.925 (+/-0.029) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': False}
# 0.925 (+/-0.035) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': True}
# 0.923 (+/-0.033) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': False}
# 0.925 (+/-0.029) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': True}
# 0.924 (+/-0.031) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': False}
# 0.924 (+/-0.030) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': True}
# 0.925 (+/-0.028) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
# 0.924 (+/-0.033) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': True}
# 0.926 (+/-0.029) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': False}
# 0.922 (+/-0.033) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': True}
# 0.923 (+/-0.031) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 50, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 50, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 100, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 100, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 200, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 2, 'max_features': 'int', 'n_estimators': 200, 'warm_start': False}
# 0.935 (+/-0.031) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': True}
# 0.935 (+/-0.030) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 50, 'warm_start': False}
# 0.936 (+/-0.030) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': True}
# 0.936 (+/-0.030) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 100, 'warm_start': False}
# 0.934 (+/-0.031) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': True}
# 0.935 (+/-0.029) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200, 'warm_start': False}
# 0.935 (+/-0.029) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': True}
# 0.934 (+/-0.030) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 50, 'warm_start': False}
# 0.935 (+/-0.028) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': True}
# 0.935 (+/-0.033) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 100, 'warm_start': False}
# 0.935 (+/-0.028) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': True}
# 0.934 (+/-0.029) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 50, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 50, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 100, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 100, 'warm_start': False}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 200, 'warm_start': True}
# nan (+/-nan) for {'bootstrap': False, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 'int', 'n_estimators': 200, 'warm_start': False}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.93      4392
#            1       0.23      0.48      0.31       295
#
#     accuracy                           0.87      4687
#    macro avg       0.60      0.69      0.62      4687
# weighted avg       0.92      0.87      0.89      4687

# %%
#调参出来的模型计算其具体的结果看一下：
clf = RandomForestClassifier(n_jobs=-1,bootstrap=False, criterion='gini',max_depth=5, max_features='sqrt',n_estimators=50, warm_start=False)
clf = clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("balanced_accuracy_score=", balanced_accuracy_score(y_pred=y_pred, y_true=y_test))
print("f1=", f1_score(y_pred=y_pred, y_true=y_test))
print("precision_score=", precision_score(y_pred=y_pred, y_true=y_test))
print("recall_score=", recall_score(y_pred=y_pred, y_true=y_test))
print("auc=", roc_auc_score(y_true=y_test, y_score=dTree.predict_proba(X_test)[:, 1]))
# Out:
# balanced_accuracy_score= 0.687588759223241
# f1= 0.3049421661409043
# precision_score= 0.22103658536585366
# recall_score= 0.4915254237288136
# auc= 0.7732275169028433

# %%
#自己搞一个Bagging模型，随机森林框架的结果感觉一般
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

clf = BaggingClassifier(DecisionTreeClassifier(), max_samples=0.5, max_features=0.5)

clf = clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("balanced_accuracy_score=", balanced_accuracy_score(y_pred=y_pred, y_true=y_test))
print("f1=", f1_score(y_pred=y_pred, y_true=y_test))
print("precision_score=", precision_score(y_pred=y_pred, y_true=y_test))
print("recall_score=", recall_score(y_pred=y_pred, y_true=y_test))
print("auc=", roc_auc_score(y_true=y_test, y_score=dTree.predict_proba(X_test)[:, 1]))
# Out:
# balanced_accuracy_score= 0.6344285449661944
# f1= 0.32500000000000007
# precision_score= 0.3433962264150943
# recall_score= 0.30847457627118646
# auc= 0.7732275169028433

# %%
from sklearn.ensemble import GradientBoostingClassifier

clf = GradientBoostingClassifier(random_state=0) 
tuned_parameters = {
                    'n_estimators': [10 , 50, 100, 200]
                    ,'learning_rate': [0.5,1,3,5]
                    ,'max_depth': [1,3,5,10]
                    }

scores = ['f1']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(clf, tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for f1
#
# Best parameters set found on development set:
#
# {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 200}
#
# Grid scores on development set:
#
# 0.925 (+/-0.038) for {'learning_rate': 0.5, 'max_depth': 1, 'n_estimators': 10}
# 0.941 (+/-0.031) for {'learning_rate': 0.5, 'max_depth': 1, 'n_estimators': 50}
# 0.943 (+/-0.027) for {'learning_rate': 0.5, 'max_depth': 1, 'n_estimators': 100}
# 0.945 (+/-0.026) for {'learning_rate': 0.5, 'max_depth': 1, 'n_estimators': 200}
# 0.942 (+/-0.029) for {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 10}
# 0.955 (+/-0.034) for {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 50}
# 0.959 (+/-0.038) for {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 100}
# 0.962 (+/-0.046) for {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 200}
# 0.951 (+/-0.029) for {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 10}
# 0.962 (+/-0.042) for {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 50}
# 0.965 (+/-0.047) for {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 100}
# 0.967 (+/-0.048) for {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 200}
# 0.963 (+/-0.040) for {'learning_rate': 0.5, 'max_depth': 10, 'n_estimators': 10}
# 0.967 (+/-0.045) for {'learning_rate': 0.5, 'max_depth': 10, 'n_estimators': 50}
# 0.967 (+/-0.046) for {'learning_rate': 0.5, 'max_depth': 10, 'n_estimators': 100}
# 0.966 (+/-0.045) for {'learning_rate': 0.5, 'max_depth': 10, 'n_estimators': 200}
# 0.931 (+/-0.035) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 10}
# 0.941 (+/-0.025) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 50}
# 0.944 (+/-0.025) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 100}
# 0.948 (+/-0.025) for {'learning_rate': 1, 'max_depth': 1, 'n_estimators': 200}
# 0.942 (+/-0.035) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 10}
# 0.957 (+/-0.046) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 50}
# 0.958 (+/-0.047) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 100}
# 0.960 (+/-0.048) for {'learning_rate': 1, 'max_depth': 3, 'n_estimators': 200}
# 0.953 (+/-0.044) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 10}
# 0.963 (+/-0.046) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 50}
# 0.963 (+/-0.047) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 100}
# 0.958 (+/-0.065) for {'learning_rate': 1, 'max_depth': 5, 'n_estimators': 200}
# 0.962 (+/-0.046) for {'learning_rate': 1, 'max_depth': 10, 'n_estimators': 10}
# 0.963 (+/-0.040) for {'learning_rate': 1, 'max_depth': 10, 'n_estimators': 50}
# 0.961 (+/-0.041) for {'learning_rate': 1, 'max_depth': 10, 'n_estimators': 100}
# 0.961 (+/-0.043) for {'learning_rate': 1, 'max_depth': 10, 'n_estimators': 200}
# 0.286 (+/-0.189) for {'learning_rate': 3, 'max_depth': 1, 'n_estimators': 10}
# 0.286 (+/-0.189) for {'learning_rate': 3, 'max_depth': 1, 'n_estimators': 50}
# 0.286 (+/-0.189) for {'learning_rate': 3, 'max_depth': 1, 'n_estimators': 100}
# 0.286 (+/-0.189) for {'learning_rate': 3, 'max_depth': 1, 'n_estimators': 200}
# 0.655 (+/-0.292) for {'learning_rate': 3, 'max_depth': 3, 'n_estimators': 10}
# 0.655 (+/-0.292) for {'learning_rate': 3, 'max_depth': 3, 'n_estimators': 50}
# 0.655 (+/-0.292) for {'learning_rate': 3, 'max_depth': 3, 'n_estimators': 100}
# 0.655 (+/-0.292) for {'learning_rate': 3, 'max_depth': 3, 'n_estimators': 200}
# 0.485 (+/-0.324) for {'learning_rate': 3, 'max_depth': 5, 'n_estimators': 10}
# 0.487 (+/-0.324) for {'learning_rate': 3, 'max_depth': 5, 'n_estimators': 50}
# 0.488 (+/-0.325) for {'learning_rate': 3, 'max_depth': 5, 'n_estimators': 100}
# 0.488 (+/-0.325) for {'learning_rate': 3, 'max_depth': 5, 'n_estimators': 200}
# 0.646 (+/-0.192) for {'learning_rate': 3, 'max_depth': 10, 'n_estimators': 10}
# 0.644 (+/-0.192) for {'learning_rate': 3, 'max_depth': 10, 'n_estimators': 50}
# 0.644 (+/-0.192) for {'learning_rate': 3, 'max_depth': 10, 'n_estimators': 100}
# 0.644 (+/-0.192) for {'learning_rate': 3, 'max_depth': 10, 'n_estimators': 200}
# 0.077 (+/-0.032) for {'learning_rate': 5, 'max_depth': 1, 'n_estimators': 10}
# 0.077 (+/-0.032) for {'learning_rate': 5, 'max_depth': 1, 'n_estimators': 50}
# 0.077 (+/-0.032) for {'learning_rate': 5, 'max_depth': 1, 'n_estimators': 100}
# 0.077 (+/-0.032) for {'learning_rate': 5, 'max_depth': 1, 'n_estimators': 200}
# 0.648 (+/-0.606) for {'learning_rate': 5, 'max_depth': 3, 'n_estimators': 10}
# 0.648 (+/-0.606) for {'learning_rate': 5, 'max_depth': 3, 'n_estimators': 50}
# 0.648 (+/-0.606) for {'learning_rate': 5, 'max_depth': 3, 'n_estimators': 100}
# 0.648 (+/-0.606) for {'learning_rate': 5, 'max_depth': 3, 'n_estimators': 200}
# 0.644 (+/-0.275) for {'learning_rate': 5, 'max_depth': 5, 'n_estimators': 10}
# 0.644 (+/-0.275) for {'learning_rate': 5, 'max_depth': 5, 'n_estimators': 50}
# 0.644 (+/-0.275) for {'learning_rate': 5, 'max_depth': 5, 'n_estimators': 100}
# 0.644 (+/-0.275) for {'learning_rate': 5, 'max_depth': 5, 'n_estimators': 200}
# 0.677 (+/-0.103) for {'learning_rate': 5, 'max_depth': 10, 'n_estimators': 10}
# 0.677 (+/-0.103) for {'learning_rate': 5, 'max_depth': 10, 'n_estimators': 50}
# 0.677 (+/-0.103) for {'learning_rate': 5, 'max_depth': 10, 'n_estimators': 100}
# 0.677 (+/-0.103) for {'learning_rate': 5, 'max_depth': 10, 'n_estimators': 200}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      4392
#            1       0.44      0.35      0.39       295
#
#     accuracy                           0.93      4687
#    macro avg       0.70      0.66      0.68      4687
# weighted avg       0.92      0.93      0.93      4687

# %%
clf = GradientBoostingClassifier(random_state=0,n_estimators=200,learning_rate=0.5,max_depth=5) 
clf = clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("balanced_accuracy_score=", balanced_accuracy_score(y_pred=y_pred, y_true=y_test))
print("f1=", f1_score(y_pred=y_pred, y_true=y_test))
print("precision_score=", precision_score(y_pred=y_pred, y_true=y_test))
print("recall_score=", recall_score(y_pred=y_pred, y_true=y_test))
print("auc=", roc_auc_score(y_true=y_test, y_score=dTree.predict_proba(X_test)[:, 1]))
# Out:
# balanced_accuracy_score= 0.6610161773332098
# f1= 0.3902439024390244
# precision_score= 0.4369747899159664
# recall_score= 0.3525423728813559
# auc= 0.7732275169028433
