# %%
# 定义全局函数便于直接调用处理
from datetime import datetime

import pandas as pd
import numpy as np
from datetime import date
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import boxcox
datapath = 'D:/outsourcing/data/'
featurepath = 'D:/outsourcing/feature/'
resultpath = 'D:/outsourcing/result/'
tmppath = 'D:/outsourcing/tmp/'

# %%
train = pd.read_csv(tmppath+"date_train.csv")
test = pd.read_csv(tmppath+'date_test.csv')
# Out:
# c:\users\32122\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2718: DtypeWarning: Columns (46,49,50) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# c:\users\32122\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2718: DtypeWarning: Columns (54,55,650) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train.head(10)
# Out:
#   seg_route_from seg_route_to seg_flight seg_cabin      seg_dep_time  \
# 0            PVG          JFK     AB1006         J  2018/12/16 20:00
# 1            PVG          JFK     AB1006         J   2019/2/18 20:00
# 2            PVG          LAX     AB1009         Y    2018/3/9 13:20
# 3            PVG          LAX     AB1009         Y    2018/1/2 13:20
# 4            PVG          JFK     AB1010         Y    2018/7/6 11:30
# 5            PVG          LAX     AB1009         Y   2019/3/24 13:20
# 6            PVG          JFK     AB1006         Y   2019/8/18 19:10
# 7            PVG          JFK     AB1006         Y    2017/7/7 19:10
# 8            PVG          JFK     AB1006         Y   2018/12/8 19:30
# 9            PVG          LAX     AB1008         Y   2017/5/25 21:00
#
#    pax_fcny  pax_tax  emd_lable  emd_lable2 gender  ...  \
# 0    4161.0   584.43          0           0      0  ...
# 1    1670.0   248.80          1           0      0  ...
# ...

# %% [markdown]
# # 采用下面这种方法，固定log变化，所有数字增加0.01

# %%
train = pd.read_csv(tmppath+"BOX_data_all_lmbda0_0.01.csv")
print(train[0:2])
# Out:
# c:\users\32122\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2718: DtypeWarning: Columns (47,48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0 seg_route_from seg_route_to seg_flight seg_cabin  \
# 0           0            PVG          LAX     AB1008         Y
# 1           1            PVG          LAX     AB1008         Y
#
#       seg_dep_time  pax_fcny   pax_tax  emd_lable2 gender  ...  \
# 0   2018/4/1 21:00 -4.595950 -4.561755           1      0  ...
# 1  2017/11/5 21:00 -4.598859 -4.562124           1      0  ...
#
#                                    pax_name_passport seg_dep_time_month  \
# 0  ffc6314419b48ffa9671f70f6699a9b9ffc6314419b48f...          -1.263273
# 1  5018e3e58463ae2d498e4babc22011d65018e3e58463ae...          -0.084370
#
#   seg_dep_time_is_workday seg_dep_time_is_holiday seg_dep_time_is_in_lieu  \
# ...

# %%
train = pd.read_csv(tmppath+"BOX_data_all_lmbda0_1.csv")
print(train.head(5))
# Out:
# c:\users\32122\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2718: DtypeWarning: Columns (47,48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0 seg_route_from seg_route_to seg_flight seg_cabin  \
# 0           0            PVG          LAX     AB1008         Y
# 1           1            PVG          LAX     AB1008         Y
# 2           2            PVG          JFK     AB1010         Y
# 3           3            PVG          JFK     AB1010         Y
# 4           4            PVG          JFK     AB1006         Y
#
#        seg_dep_time  pax_fcny   pax_tax  emd_lable2 gender  ...  \
# 0    2018/4/1 21:00  0.000093  0.000444           1      0  ...
# 1   2017/11/5 21:00  0.000063  0.000440           1      0  ...
# 2   2017/2/28 11:30  0.000096  0.000366           1      0  ...
# 3  2018/10/13 11:30  0.000084  0.000357           1      F  ...
# ...

# %%
train = pd.read_csv(tmppath+"BOX_train.csv")
print(train.head(5))
# Out:
#   seg_route_from seg_route_to seg_flight seg_cabin      seg_dep_time  \
# 0            PVG          LAX     AB1008         Y    2018/4/1 21:00
# 1            PVG          LAX     AB1008         Y   2017/11/5 21:00
# 2            PVG          JFK     AB1010         Y   2017/2/28 11:30
# 3            PVG          JFK     AB1010         Y  2018/10/13 11:30
# 4            PVG          JFK     AB1006         Y   2018/3/28 19:10
#
#    pax_fcny   pax_tax  emd_lable2 gender age  ...  \
# 0 -4.595950 -4.561755           1      0   0  ...
# 1 -4.598859 -4.562124           1      0   0  ...
# 2 -4.595601 -4.569174           1      0   0  ...
# 3 -4.596833 -4.570091           1      F   0  ...
# 4 -4.598160 -4.562109           1      0   0  ...
#
#                                    pax_name_passport seg_dep_time_month  \
# 0  ffc6314419b48ffa9671f70f6699a9b9ffc6314419b48f...          -1.263273
# 1  5018e3e58463ae2d498e4babc22011d65018e3e58463ae...          -0.084370
# ...

# %%
train = pd.read_csv(tmppath+"date_train.csv")
# Out:
# c:\users\32122\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2718: DtypeWarning: Columns (46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train.head(5)
# Out:
#   seg_route_from seg_route_to seg_flight seg_cabin      seg_dep_time  \
# 0            PVG          LAX     AB1008         Y    2018/4/1 21:00
# 1            PVG          LAX     AB1008         Y   2017/11/5 21:00
# 2            PVG          JFK     AB1010         Y   2017/2/28 11:30
# 3            PVG          JFK     AB1010         Y  2018/10/13 11:30
# 4            PVG          JFK     AB1006         Y   2018/3/28 19:10
#
#    pax_fcny  pax_tax  emd_lable2 gender age  ...  \
# 0     395.0   282.51           1      0   0  ...
# 1     270.0   280.06           1      0   0  ...
# 2     410.0   233.36           1      0   0  ...
# 3     357.0   227.31           1      F   0  ...
# 4     300.0   280.16           1      0   0  ...
#
#                                    pax_name_passport seg_dep_time_month  \
# 0  ffc6314419b48ffa9671f70f6699a9b9ffc6314419b48f...                  4
# 1  5018e3e58463ae2d498e4babc22011d65018e3e58463ae...                 11
# ...

# %%
train = pd.read_csv(tmppath + "BOX_train.csv")
test = pd.read_csv(tmppath + "BOX_test.csv")
# Out:
# c:\users\32122\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2718: DtypeWarning: Columns (46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train.head(5)
# Out:
#   seg_route_from seg_route_to seg_flight seg_cabin      seg_dep_time  \
# 0            PVG          LAX     AB1008         Y    2018/4/1 21:00
# 1            PVG          LAX     AB1008         Y   2017/11/5 21:00
# 2            PVG          JFK     AB1010         Y   2017/2/28 11:30
# 3            PVG          JFK     AB1010         Y  2018/10/13 11:30
# 4            PVG          JFK     AB1006         Y   2018/3/28 19:10
#
#    pax_fcny   pax_tax  emd_lable2 gender age  ...  \
# 0  0.000092  0.000439           1      0   0  ...
# 1  0.000063  0.000435           1      0   0  ...
# 2  0.000095  0.000363           1      0   0  ...
# 3  0.000083  0.000354           1      F   0  ...
# 4  0.000070  0.000435           1      0   0  ...
#
#                                    pax_name_passport seg_dep_time_month  \
# 0  ffc6314419b48ffa9671f70f6699a9b9ffc6314419b48f...           0.258122
# 1  5018e3e58463ae2d498e4babc22011d65018e3e58463ae...           0.778517
# ...

# %%
test.head(5)
# Out:
#   seg_route_from seg_route_to seg_flight seg_cabin      seg_dep_time  \
# 0            PVG          JFK     AB1006         J  2018/12/16 20:00
# 1            PVG          JFK     AB1006         J   2019/2/18 20:00
# 2            PVG          LAX     AB1009         Y    2018/3/9 13:20
# 3            PVG          LAX     AB1009         Y    2018/1/2 13:20
# 4            PVG          JFK     AB1010         Y    2018/7/6 11:30
#
#    pax_fcny   pax_tax  emd_lable2 gender age  ...  \
# 0  0.000890  0.000898           0      0   0  ...
# 1  0.000377  0.000387           0      0   0  ...
# 2  0.000057  0.000468           0      0   0  ...
# 3  0.000310  0.000701           0      0   0  ...
# 4  0.000156  0.000441           1      M   0  ...
#
#                                    pax_name_passport seg_dep_time_month  \
# 0  9612c51f08718e48b1361e415ef55be99612c51f08718e...           0.846096
# 1  c7ca533cd9da4c4bf3d597248f90bc6ec7ca533cd9da4c...           0.089156
# ...

# %%
train = pd.read_csv(tmppath + "BOX_mi_en_train.csv")
test = pd.read_csv(tmppath + "BOX_mi_en_test.csv")

# %%
train.head(5)
# Out:
#    seg_route_from  seg_route_to  seg_flight  seg_cabin  pax_fcny   pax_tax  \
# 0        0.062948      0.062579    0.065516   0.072386  0.017424  0.020562
# 1        0.062948      0.062579    0.065516   0.072386  0.011948  0.020394
# 2        0.062948      0.092602    0.107637   0.072386  0.018080  0.017021
# 3        0.062948      0.092602    0.107637   0.072386  0.015761  0.016586
# 4        0.062948      0.092602    0.081655   0.072386  0.013260  0.020394
#
#      gender       age  residence_country  nation_name  ...  \
# 0  0.058618  0.060162           0.059297     0.061196  ...
# 1  0.058618  0.060162           0.059297     0.061196  ...
# 2  0.058618  0.060162           0.059297     0.061196  ...
# 3  0.083441  0.060162           0.078555     0.061196  ...
# 4  0.058618  0.060162           0.059297     0.061196  ...
#
#    seg_dep_time_month  seg_dep_time_is_workday  seg_dep_time_is_holiday  \
# 0            0.304962                      1.0                      0.0
# ...

# %%
test.head(5)
# Out:
#    seg_route_from  seg_route_to  seg_flight  seg_cabin  pax_fcny   pax_tax  \
# 0        0.062948      0.092602    0.081655   0.000338  0.168990  0.042061
# 1        0.062948      0.092602    0.081655   0.000338  0.071642  0.018138
# 2        0.062948      0.062579    0.073113   0.072386  0.010760  0.021924
# 3        0.062948      0.062579    0.073113   0.072386  0.058834  0.032858
# 4        0.062948      0.092602    0.107637   0.072386  0.029598  0.020684
#
#      gender       age  residence_country  nation_name  ...  \
# 0  0.058618  0.060162           0.059297     0.061196  ...
# 1  0.058618  0.060162           0.059297     0.061196  ...
# 2  0.058618  0.060162           0.059297     0.061196  ...
# 3  0.058618  0.060162           0.059297     0.061196  ...
# 4  0.077714  0.060162           0.078555     0.061196  ...
#
#    seg_dep_time_month  seg_dep_time_is_workday  seg_dep_time_is_holiday  \
# 0            1.000000                      1.0                      0.0
# ...
